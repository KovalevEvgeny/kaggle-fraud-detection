# %%
import datetime
import gc
import math
import os
import pickle
import random

from functools import partial
from time import time

import lightgbm as lgb

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold, KFold, TimeSeriesSplit
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
INPUT_PATH = '/kaggle/input/ieee-fraud-detection'

COL_ID = 'TransactionID'
COL_DT = 'TransactionDT'
COL_AMOUNT = 'TransactionAmt'
COL_TARGET = 'isFraud'

START_DATE = '2017-11-30'

# %%
EMAIL_MAP = {
    'gmail': 'google', 'att.net': 'att', 'twc.com': 'spectrum', 'scranton.edu': 'other', 'optonline.net': 'other', 
    'hotmail.co.uk': 'microsoft', 'comcast.net': 'other', 'yahoo.com.mx': 'yahoo', 'yahoo.fr': 'yahoo', 
    'yahoo.es': 'yahoo', 'charter.net': 'spectrum', 'live.com': 'microsoft', 'aim.com': 'aol', 
    'hotmail.de': 'microsoft', 'centurylink.net': 'centurylink', 'gmail.com': 'google', 'me.com': 'apple', 
    'earthlink.net': 'other', 'gmx.de': 'other', 'web.de': 'other', 'cfl.rr.com': 'other', 'hotmail.com': 'microsoft', 
    'protonmail.com': 'other', 'hotmail.fr': 'microsoft', 'windstream.net': 'other', 'outlook.es': 'microsoft', 
    'yahoo.co.jp': 'yahoo', 'yahoo.de': 'yahoo', 'servicios-ta.com': 'other', 'netzero.net': 'other', 
    'suddenlink.net': 'other', 'roadrunner.com': 'other', 'sc.rr.com': 'other', 'live.fr': 'microsoft', 
    'verizon.net': 'yahoo', 'msn.com': 'microsoft', 'q.com': 'centurylink', 'prodigy.net.mx': 'att', 
    'frontier.com': 'yahoo', 'anonymous.com': 'other', 'rocketmail.com': 'yahoo', 'sbcglobal.net': 'att', 
    'frontiernet.net': 'yahoo', 'ymail.com': 'yahoo', 'outlook.com': 'microsoft', 'mail.com': 'other', 
    'bellsouth.net': 'other', 'embarqmail.com': 'centurylink', 'cableone.net': 'other', 'hotmail.es': 'microsoft', 
    'mac.com': 'apple', 'yahoo.co.uk': 'yahoo', 'netzero.com': 'other', 'yahoo.com': 'yahoo', 'live.com.mx': 'microsoft', 
    'ptd.net': 'other', 'cox.net': 'other', 'aol.com': 'aol', 'juno.com': 'other', 'icloud.com': 'apple'
}

# %%
def seed_everything(seed=13):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)


def save_to_disk(df, filename):
    with open(filename, 'wb') as handle:
        pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def load_df(path, filenames):
    assert len(filenames) == 2
    dfs = [pd.read_csv(os.path.join(path, f), index_col=COL_ID) for f in filenames]
    return dfs[0].merge(dfs[1], how='left', left_index=True, right_index=True)


def split_train_val(x, y, val_start, val_end):
    assert val_start < val_end
    val = (x[COL_DT] >= val_start) & (x[COL_DT] < val_end)
    x_train, x_val = x[~val], x[val]
    indices = lambda df: df.index.values.astype(int)
    y_train, y_val = y[indices(x_train)], y[indices(x_val)]
    return x_train, y_train, x_val, y_val


def split_label_inputs(df):
    return df[COL_TARGET], df.drop(COL_TARGET, axis=1)

# %%
INT_TYPES = [np.int8, np.int16, np.int32, np.int64]
UINT_TYPES = [np.uint8, np.uint16, np.uint32, np.uint64]
IGNORE_COLUMNS = [
    'TransactionAmt_log'
]


def downcast_int(df, col, min_val, max_val):    
    if min_val < 0:
        for i, dtype in enumerate(INT_TYPES):
            if (i == 3) or (np.iinfo(dtype).min < min_val and max_val < np.iinfo(dtype).max):
                df[col] = df[col].astype(dtype); break
    else:
        for i, dtype in enumerate(UINT_TYPES):
            if (i == 3) or (max_val < np.iinfo(dtype).max):
                df[col] = df[col].astype(dtype); break


def mem_usg_mb(df):
    return df.memory_usage().sum() / 1024**2


# original: https://www.kaggle.com/mjbahmani/reducing-memory-size-for-ieee
def reduce_mem_usage(df):
    init_mem_usg = mem_usg_mb(df)
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in df.columns:
        if col in IGNORE_COLUMNS or df[col].dtype == object:
            continue
        dtype_before = df[col].dtype
        min_val, max_val = df[col].min(), df[col].max()
        # Integer does not support NA, therefore, NA needs to be filled
        if not np.isfinite(df[col]).all(): 
            NAlist.append(col)
            df[col].fillna(-32222, inplace=True) # changed here mn-1 -> -32222
        # test if column can be converted to an integer
        # https://stackoverflow.com/questions/21583758/how-to-check-if-a-float-value-is-a-whole-number       
        if (df[col] % 1 == 0).all():
            downcast_int(df, col, min_val, max_val)  
        else:
            df[col] = df[col].astype(np.float32)
        print("{}, range: ({}, {}), dtype: {} -> {}".format(
            col, min_val, max_val, dtype_before, df[col].dtype))
    print("\n *** DONE ***")
    mem_usg = mem_usg_mb(df) 
    print("Memory usage: %.02f -> %.02f MB" % (init_mem_usg, mem_usg))
    print("This is {:.02f}% of the initial size".format(100 * mem_usg / init_mem_usg))
    return df, NAlist

# %%
def parse_email_suffix(email):
    if email is np.nan:
        return 0, np.nan, np.nan
    parts = email.split('.') 
    middle = parts[-2] if len(parts) > 2 else parts[-1]
    last = parts[-1]
    return len(parts), middle, last

# %%
def feature_cents(df):
    return (np.modf(df[COL_AMOUNT])[0] * 1000).astype(np.uint16)


def feature_days(df):
    return (df[COL_DT] / (24 * 60 * 60)).astype(np.uint16)


def parse_datetime(df):
    start_date = datetime.datetime.strptime(START_DATE, '%Y-%m-%d')
    return df[COL_DT].apply(lambda x: (start_date + datetime.timedelta(seconds = x)))


def frequency(col, dfs):
    counts = pd.concat(map(lambda df: df[col], dfs), ignore_index=True).value_counts(dropna=False)
    return map(lambda df: df[col].map(counts), dfs)

# %% [markdown]
# # Data preparation

# %%
# %%time
df_train = load_df(INPUT_PATH, ['train_transaction.csv', 'train_identity.csv'])
df_test = load_df(INPUT_PATH, ['test_transaction.csv', 'test_identity.csv'])
df_train.shape, df_test.shape
# Out:
# CPU times: user 59.1 s, sys: 14.5 s, total: 1min 13s
# Wall time: 1min 10s
# ((590540, 433), (506691, 432))

# %%
all_dfs = [df_train, df_test]
encode_labels_cols = []

for i, df in enumerate(all_dfs):
    df['Cents'] = feature_cents(df)
    df[COL_AMOUNT+'_log'] = np.log(df[COL_AMOUNT])
    
    dt_ = parse_datetime(df)
    df['Hour'] = dt_.dt.hour
    df['DayOfWeek'] = dt_.dt.weekday
    df['DayOfMonth'] = dt_.dt.day
    df['MonthFraction'] = (dt_.dt.day / dt_.dt.days_in_month * 100).astype(np.uint8)
    df['isDecember'] = dt_.dt.month == 12

# %%
dt_m = parse_datetime(df_train).dt.date.astype('str').str[:7]
dt_m.value_counts()
# Out:
# 2017-12    137321
# 2018-03    101632
# 2018-01     92585
# 2018-05     89326
# 2018-02     86021
# 2018-04     83655
# Name: TransactionDT, dtype: int64

# %%
interactions = [
    'card1__addr1', 'card1__card5', 'card2__dist1', 'card2__id_20', 'card5__P_emaildomain',
    'card1__card2', 
    'card1__card2__card3__card5', 
    'card1__card2__card3__card5__addr1__addr2',
]
rename = {
    'card1__card2': 'uuid',
    'card1__card2__card3__card5': 'uuid2',
    'card1__card2__card3__card5__addr1__addr2': 'uuid3'
}
encode_freq_cols = ['card1__addr1', 'card1__card5', 'uuid3']
groups = [
    (['uuid2', 'ProductCD'], COL_AMOUNT, 'mean'),
    (['uuid2', 'addr1'], 'dist2', 'mean'),
    ('V307', 'V313', 'mean'),
    ('uuid3', COL_AMOUNT, ['mean', 'std']),
    ('uuid2', COL_AMOUNT, 'mean'),
    ('uuid', COL_AMOUNT, 'mean'),
    ('card1', COL_AMOUNT, 'mean'),
]
drop = ['uuid', 'uuid2', 'uuid3']

for inter in interactions:
    cols = inter.split('__')
    col = rename[inter] if inter in rename else inter
    for df in all_dfs:
        df[col] = df[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)    
    if col in encode_freq_cols:
        for df, freq in zip(all_dfs, frequency(col, all_dfs)):
            df[col+'_count'] = freq
    if col not in drop:
        encode_labels_cols.append(col)
    gc.collect()

for df in all_dfs:
    for group, target, aggs in groups:
        if not isinstance(group, list):
            group = [group]
        if not isinstance(aggs, list):
            aggs = [aggs]
        for agg in aggs:
            col = f'{target}_{agg}_by_{"_".join(group)}'
            df[col] = df.groupby(group)[target].transform(agg)
    for col in drop:
        df.drop([col], axis=1, inplace=True)
gc.collect()
# Out:
# 0

# %%
encode_freq_cols = [
    'card1', 'card2', 'card5', 
    'addr1', 'addr2', 'dist1',
    'C1', 'C2', 'C5', 'C6', 'C7', 'C9', 'C11', 'C13', 'C14', 
    'P_emaildomain', 'DeviceInfo'
]
    
for col in encode_freq_cols:
    for df, freq in zip(all_dfs, frequency(col, all_dfs)):
        df[col+'_count'] = freq

# %%
na_cols = [
    'D2', 'D3', 'D5', 'D6', 'D7', 'D13', 'D14',
    'M4', 'M5', 'M6', 'M7', 'M8',
]

for df in all_dfs:
    for col in na_cols:
        df[col+'_na'] = df[col].isna()

# %%
for df in all_dfs:
    for col in ['P_emaildomain', 'R_emaildomain']:
        temp = df[col].apply(lambda x: parse_email_suffix(x))
        df[col+'_parts'] = temp.map(lambda x: x[0])
        df[col+'_sfx2']  = temp.map(lambda x: x[1])
        df[col+'_sfx1']  = temp.map(lambda x: x[2])
        
        #https://www.kaggle.com/c/ieee-fraud-detection/discussion/100499#latest-579654
        df[col+'_bin'] = df[col].map(EMAIL_MAP)
        
        encode_labels_cols.extend([
            col+'_sfx2', 
            col+'_sfx1', 
            col+'_bin'
        ])

# %%
def str_contains(df, col, val):
    return df[col].str.contains(val, case=False).fillna(False)


for df in all_dfs:
    col = 'Browser'
    df[col] = -1
    search = partial(str_contains, df, 'id_31')
    for i, browser in enumerate(['chrome', 'safari', 'ie ', 'firefox', 'edge', 'samsung', 'opera']):
        df.loc[search(browser), [col]] = i
    df.loc[(df['id_31'] == 'ie'), [col]] = 2
    
for df in all_dfs:
    col = 'OS'
    df[col] = -1
    search = partial(str_contains, df, 'id_30')
    for i, os_name in enumerate(['windows', 'ios', 'mac', 'android', 'linux']):
        df.loc[search(os_name), [col]] = i

# %%
# %%time
df_train, na_train = reduce_mem_usage(df_train)
# Out:
# isFraud, range: (0, 1), dtype: int64 -> uint8
# TransactionDT, range: (86400, 15811131), dtype: int64 -> uint32
# TransactionAmt, range: (0.251, 31937.391), dtype: float64 -> float32
# card1, range: (1000, 18396), dtype: int64 -> uint16
# card2, range: (100.0, 600.0), dtype: float64 -> uint16
# card3, range: (100.0, 231.0), dtype: float64 -> uint8
# card5, range: (100.0, 237.0), dtype: float64 -> uint8
# addr1, range: (100.0, 540.0), dtype: float64 -> uint16
# addr2, range: (10.0, 102.0), dtype: float64 -> uint8
# dist1, range: (0.0, 10286.0), dtype: float64 -> uint16
# dist2, range: (0.0, 11623.0), dtype: float64 -> uint16
# C1, range: (0.0, 4685.0), dtype: float64 -> uint16
# C2, range: (0.0, 5691.0), dtype: float64 -> uint16
# C3, range: (0.0, 26.0), dtype: float64 -> uint8
# C4, range: (0.0, 2253.0), dtype: float64 -> uint16
# C5, range: (0.0, 349.0), dtype: float64 -> uint16
# C6, range: (0.0, 2253.0), dtype: float64 -> uint16
# C7, range: (0.0, 2255.0), dtype: float64 -> uint16
# C8, range: (0.0, 3331.0), dtype: float64 -> uint16
# C9, range: (0.0, 210.0), dtype: float64 -> uint8
# C10, range: (0.0, 3257.0), dtype: float64 -> uint16
# C11, range: (0.0, 3188.0), dtype: float64 -> uint16
# C12, range: (0.0, 3188.0), dtype: float64 -> uint16
# C13, range: (0.0, 2918.0), dtype: float64 -> uint16
# C14, range: (0.0, 1429.0), dtype: float64 -> uint16
# D1, range: (0.0, 640.0), dtype: float64 -> uint16
# D2, range: (0.0, 640.0), dtype: float64 -> uint16
# D3, range: (0.0, 819.0), dtype: float64 -> uint16
# D4, range: (-122.0, 869.0), dtype: float64 -> int16
# D5, range: (0.0, 819.0), dtype: float64 -> uint16
# D6, range: (-83.0, 873.0), dtype: float64 -> int16
# D7, range: (0.0, 843.0), dtype: float64 -> uint16
# D8, range: (0.0, 1707.7916259765625), dtype: float64 -> float32
# D9, range: (0.0, 0.9583330154418944), dtype: float64 -> float32
# D10, range: (0.0, 876.0), dtype: float64 -> uint16
# D11, range: (-53.0, 670.0), dtype: float64 -> int16
# D12, range: (-83.0, 648.0), dtype: float64 -> int16
# D13, range: (0.0, 847.0), dtype: float64 -> uint16
# D14, range: (-193.0, 878.0), dtype: float64 -> int16
# D15, range: (-83.0, 879.0), dtype: float64 -> int16
# V1, range: (0.0, 1.0), dtype: float64 -> uint8
# V2, range: (0.0, 8.0), dtype: float64 -> uint8
# V3, range: (0.0, 9.0), dtype: float64 -> uint8
# V4, range: (0.0, 6.0), dtype: float64 -> uint8
# V5, range: (0.0, 6.0), dtype: float64 -> uint8
# V6, range: (0.0, 9.0), dtype: float64 -> uint8
# V7, range: (0.0, 9.0), dtype: float64 -> uint8
# V8, range: (0.0, 8.0), dtype: float64 -> uint8
# V9, range: (0.0, 8.0), dtype: float64 -> uint8
# V10, range: (0.0, 4.0), dtype: float64 -> uint8
# V11, range: (0.0, 5.0), dtype: float64 -> uint8
# V12, range: (0.0, 3.0), dtype: float64 -> uint8
# V13, range: (0.0, 6.0), dtype: float64 -> uint8
# V14, range: (0.0, 1.0), dtype: float64 -> uint8
# V15, range: (0.0, 7.0), dtype: float64 -> uint8
# V16, range: (0.0, 15.0), dtype: float64 -> uint8
# V17, range: (0.0, 15.0), dtype: float64 -> uint8
# V18, range: (0.0, 15.0), dtype: float64 -> uint8
# V19, range: (0.0, 7.0), dtype: float64 -> uint8
# V20, range: (0.0, 15.0), dtype: float64 -> uint8
# V21, range: (0.0, 5.0), dtype: float64 -> uint8
# V22, range: (0.0, 8.0), dtype: float64 -> uint8
# V23, range: (0.0, 13.0), dtype: float64 -> uint8
# V24, range: (0.0, 13.0), dtype: float64 -> uint8
# V25, range: (0.0, 7.0), dtype: float64 -> uint8
# V26, range: (0.0, 13.0), dtype: float64 -> uint8
# V27, range: (0.0, 4.0), dtype: float64 -> uint8
# V28, range: (0.0, 4.0), dtype: float64 -> uint8
# V29, range: (0.0, 5.0), dtype: float64 -> uint8
# V30, range: (0.0, 9.0), dtype: float64 -> uint8
# V31, range: (0.0, 7.0), dtype: float64 -> uint8
# V32, range: (0.0, 15.0), dtype: float64 -> uint8
# V33, range: (0.0, 7.0), dtype: float64 -> uint8
# V34, range: (0.0, 13.0), dtype: float64 -> uint8
# V35, range: (0.0, 3.0), dtype: float64 -> uint8
# V36, range: (0.0, 5.0), dtype: float64 -> uint8
# V37, range: (0.0, 54.0), dtype: float64 -> uint8
# V38, range: (0.0, 54.0), dtype: float64 -> uint8
# V39, range: (0.0, 15.0), dtype: float64 -> uint8
# V40, range: (0.0, 24.0), dtype: float64 -> uint8
# V41, range: (0.0, 1.0), dtype: float64 -> uint8
# V42, range: (0.0, 8.0), dtype: float64 -> uint8
# V43, range: (0.0, 8.0), dtype: float64 -> uint8
# V44, range: (0.0, 48.0), dtype: float64 -> uint8
# V45, range: (0.0, 48.0), dtype: float64 -> uint8
# V46, range: (0.0, 6.0), dtype: float64 -> uint8
# V47, range: (0.0, 12.0), dtype: float64 -> uint8
# V48, range: (0.0, 5.0), dtype: float64 -> uint8
# V49, range: (0.0, 5.0), dtype: float64 -> uint8
# V50, range: (0.0, 5.0), dtype: float64 -> uint8
# V51, range: (0.0, 6.0), dtype: float64 -> uint8
# V52, range: (0.0, 12.0), dtype: float64 -> uint8
# V53, range: (0.0, 5.0), dtype: float64 -> uint8
# V54, range: (0.0, 6.0), dtype: float64 -> uint8
# V55, range: (0.0, 17.0), dtype: float64 -> uint8
# V56, range: (0.0, 51.0), dtype: float64 -> uint8
# V57, range: (0.0, 6.0), dtype: float64 -> uint8
# V58, range: (0.0, 10.0), dtype: float64 -> uint8
# V59, range: (0.0, 16.0), dtype: float64 -> uint8
# V60, range: (0.0, 16.0), dtype: float64 -> uint8
# V61, range: (0.0, 6.0), dtype: float64 -> uint8
# V62, range: (0.0, 10.0), dtype: float64 -> uint8
# V63, range: (0.0, 7.0), dtype: float64 -> uint8
# V64, range: (0.0, 7.0), dtype: float64 -> uint8
# V65, range: (0.0, 1.0), dtype: float64 -> uint8
# V66, range: (0.0, 7.0), dtype: float64 -> uint8
# V67, range: (0.0, 8.0), dtype: float64 -> uint8
# V68, range: (0.0, 2.0), dtype: float64 -> uint8
# V69, range: (0.0, 5.0), dtype: float64 -> uint8
# V70, range: (0.0, 6.0), dtype: float64 -> uint8
# V71, range: (0.0, 6.0), dtype: float64 -> uint8
# V72, range: (0.0, 10.0), dtype: float64 -> uint8
# V73, range: (0.0, 7.0), dtype: float64 -> uint8
# V74, range: (0.0, 8.0), dtype: float64 -> uint8
# V75, range: (0.0, 4.0), dtype: float64 -> uint8
# V76, range: (0.0, 6.0), dtype: float64 -> uint8
# V77, range: (0.0, 30.0), dtype: float64 -> uint8
# V78, range: (0.0, 31.0), dtype: float64 -> uint8
# V79, range: (0.0, 7.0), dtype: float64 -> uint8
# V80, range: (0.0, 19.0), dtype: float64 -> uint8
# V81, range: (0.0, 19.0), dtype: float64 -> uint8
# V82, range: (0.0, 7.0), dtype: float64 -> uint8
# V83, range: (0.0, 7.0), dtype: float64 -> uint8
# V84, range: (0.0, 7.0), dtype: float64 -> uint8
# V85, range: (0.0, 7.0), dtype: float64 -> uint8
# V86, range: (0.0, 30.0), dtype: float64 -> uint8
# V87, range: (0.0, 30.0), dtype: float64 -> uint8
# V88, range: (0.0, 1.0), dtype: float64 -> uint8
# V89, range: (0.0, 2.0), dtype: float64 -> uint8
# V90, range: (0.0, 5.0), dtype: float64 -> uint8
# V91, range: (0.0, 6.0), dtype: float64 -> uint8
# V92, range: (0.0, 7.0), dtype: float64 -> uint8
# V93, range: (0.0, 7.0), dtype: float64 -> uint8
# V94, range: (0.0, 2.0), dtype: float64 -> uint8
# V95, range: (0.0, 880.0), dtype: float64 -> uint16
# V96, range: (0.0, 1410.0), dtype: float64 -> uint16
# V97, range: (0.0, 976.0), dtype: float64 -> uint16
# V98, range: (0.0, 12.0), dtype: float64 -> uint8
# V99, range: (0.0, 88.0), dtype: float64 -> uint8
# V100, range: (0.0, 28.0), dtype: float64 -> uint8
# V101, range: (0.0, 869.0), dtype: float64 -> uint16
# V102, range: (0.0, 1285.0), dtype: float64 -> uint16
# V103, range: (0.0, 928.0), dtype: float64 -> uint16
# V104, range: (0.0, 15.0), dtype: float64 -> uint8
# V105, range: (0.0, 99.0), dtype: float64 -> uint8
# V106, range: (0.0, 55.0), dtype: float64 -> uint8
# V107, range: (0.0, 1.0), dtype: float64 -> uint8
# V108, range: (0.0, 7.0), dtype: float64 -> uint8
# V109, range: (0.0, 7.0), dtype: float64 -> uint8
# V110, range: (0.0, 7.0), dtype: float64 -> uint8
# V111, range: (0.0, 9.0), dtype: float64 -> uint8
# V112, range: (0.0, 9.0), dtype: float64 -> uint8
# V113, range: (0.0, 9.0), dtype: float64 -> uint8
# V114, range: (0.0, 6.0), dtype: float64 -> uint8
# V115, range: (0.0, 6.0), dtype: float64 -> uint8
# V116, range: (0.0, 6.0), dtype: float64 -> uint8
# V117, range: (0.0, 3.0), dtype: float64 -> uint8
# V118, range: (0.0, 3.0), dtype: float64 -> uint8
# V119, range: (0.0, 3.0), dtype: float64 -> uint8
# V120, range: (0.0, 3.0), dtype: float64 -> uint8
# V121, range: (0.0, 3.0), dtype: float64 -> uint8
# V122, range: (0.0, 3.0), dtype: float64 -> uint8
# V123, range: (0.0, 13.0), dtype: float64 -> uint8
# V124, range: (0.0, 13.0), dtype: float64 -> uint8
# V125, range: (0.0, 13.0), dtype: float64 -> uint8
# V126, range: (0.0, 160000.0), dtype: float64 -> float32
# V127, range: (0.0, 160000.0), dtype: float64 -> float32
# V128, range: (0.0, 160000.0), dtype: float64 -> float32
# V129, range: (0.0, 55125.0), dtype: float64 -> float32
# V130, range: (0.0, 55125.0), dtype: float64 -> float32
# V131, range: (0.0, 55125.0), dtype: float64 -> float32
# V132, range: (0.0, 93736.0), dtype: float64 -> float32
# V133, range: (0.0, 133915.0), dtype: float64 -> float32
# V134, range: (0.0, 98476.0), dtype: float64 -> float32
# V135, range: (0.0, 90750.0), dtype: float64 -> float32
# V136, range: (0.0, 90750.0), dtype: float64 -> float32
# V137, range: (0.0, 90750.0), dtype: float64 -> float32
# V138, range: (0.0, 22.0), dtype: float64 -> uint8
# V139, range: (0.0, 33.0), dtype: float64 -> uint8
# V140, range: (0.0, 33.0), dtype: float64 -> uint8
# V141, range: (0.0, 5.0), dtype: float64 -> uint8
# V142, range: (0.0, 9.0), dtype: float64 -> uint8
# V143, range: (0.0, 869.0), dtype: float64 -> uint16
# V144, range: (0.0, 62.0), dtype: float64 -> uint8
# V145, range: (0.0, 297.0), dtype: float64 -> uint16
# V146, range: (0.0, 24.0), dtype: float64 -> uint8
# V147, range: (0.0, 26.0), dtype: float64 -> uint8
# V148, range: (0.0, 20.0), dtype: float64 -> uint8
# V149, range: (0.0, 20.0), dtype: float64 -> uint8
# V150, range: (1.0, 3389.0), dtype: float64 -> uint16
# V151, range: (1.0, 57.0), dtype: float64 -> uint8
# V152, range: (1.0, 69.0), dtype: float64 -> uint8
# V153, range: (0.0, 18.0), dtype: float64 -> uint8
# V154, range: (0.0, 18.0), dtype: float64 -> uint8
# V155, range: (0.0, 24.0), dtype: float64 -> uint8
# V156, range: (0.0, 24.0), dtype: float64 -> uint8
# V157, range: (0.0, 24.0), dtype: float64 -> uint8
# V158, range: (0.0, 24.0), dtype: float64 -> uint8
# V159, range: (0.0, 55125.0), dtype: float64 -> float32
# V160, range: (0.0, 641511.4375), dtype: float64 -> float32
# V161, range: (0.0, 3300.0), dtype: float64 -> float32
# V162, range: (0.0, 3300.0), dtype: float64 -> float32
# V163, range: (0.0, 3300.0), dtype: float64 -> float32
# V164, range: (0.0, 93736.0), dtype: float64 -> float32
# V165, range: (0.0, 98476.0), dtype: float64 -> float32
# V166, range: (0.0, 104060.0), dtype: float64 -> float32
# V167, range: (0.0, 872.0), dtype: float64 -> uint16
# V168, range: (0.0, 964.0), dtype: float64 -> uint16
# V169, range: (0.0, 19.0), dtype: float64 -> uint8
# V170, range: (0.0, 48.0), dtype: float64 -> uint8
# V171, range: (0.0, 61.0), dtype: float64 -> uint8
# V172, range: (0.0, 31.0), dtype: float64 -> uint8
# V173, range: (0.0, 7.0), dtype: float64 -> uint8
# V174, range: (0.0, 8.0), dtype: float64 -> uint8
# V175, range: (0.0, 14.0), dtype: float64 -> uint8
# V176, range: (0.0, 48.0), dtype: float64 -> uint8
# V177, range: (0.0, 861.0), dtype: float64 -> uint16
# V178, range: (0.0, 1235.0), dtype: float64 -> uint16
# V179, range: (0.0, 920.0), dtype: float64 -> uint16
# V180, range: (0.0, 83.0), dtype: float64 -> uint8
# V181, range: (0.0, 24.0), dtype: float64 -> uint8
# V182, range: (0.0, 83.0), dtype: float64 -> uint8
# V183, range: (0.0, 41.0), dtype: float64 -> uint8
# V184, range: (0.0, 16.0), dtype: float64 -> uint8
# V185, range: (0.0, 31.0), dtype: float64 -> uint8
# V186, range: (0.0, 38.0), dtype: float64 -> uint8
# V187, range: (0.0, 218.0), dtype: float64 -> uint8
# V188, range: (0.0, 30.0), dtype: float64 -> uint8
# V189, range: (0.0, 30.0), dtype: float64 -> uint8
# V190, range: (0.0, 42.0), dtype: float64 -> uint8
# V191, range: (0.0, 21.0), dtype: float64 -> uint8
# V192, range: (0.0, 44.0), dtype: float64 -> uint8
# V193, range: (0.0, 37.0), dtype: float64 -> uint8
# V194, range: (0.0, 7.0), dtype: float64 -> uint8
# V195, range: (0.0, 16.0), dtype: float64 -> uint8
# V196, range: (0.0, 38.0), dtype: float64 -> uint8
# V197, range: (0.0, 14.0), dtype: float64 -> uint8
# V198, range: (0.0, 21.0), dtype: float64 -> uint8
# V199, range: (0.0, 45.0), dtype: float64 -> uint8
# V200, range: (0.0, 45.0), dtype: float64 -> uint8
# V201, range: (0.0, 55.0), dtype: float64 -> uint8
# V202, range: (0.0, 104060.0), dtype: float64 -> float32
# V203, range: (0.0, 139777.0), dtype: float64 -> float32
# V204, range: (0.0, 104060.0), dtype: float64 -> float32
# V205, range: (0.0, 55125.0), dtype: float64 -> float32
# V206, range: (0.0, 55125.0), dtype: float64 -> float32
# V207, range: (0.0, 55125.0), dtype: float64 -> float32
# V208, range: (0.0, 3300.0), dtype: float64 -> float32
# V209, range: (0.0, 8050.0), dtype: float64 -> float32
# V210, range: (0.0, 3300.0), dtype: float64 -> float32
# V211, range: (0.0, 92888.0), dtype: float64 -> float32
# V212, range: (0.0, 129006.0), dtype: float64 -> float32
# V213, range: (0.0, 97628.0), dtype: float64 -> float32
# V214, range: (0.0, 104060.0), dtype: float64 -> float32
# V215, range: (0.0, 104060.0), dtype: float64 -> float32
# V216, range: (0.0, 104060.0), dtype: float64 -> float32
# V217, range: (0.0, 303.0), dtype: float64 -> uint16
# V218, range: (0.0, 400.0), dtype: float64 -> uint16
# V219, range: (0.0, 378.0), dtype: float64 -> uint16
# V220, range: (0.0, 25.0), dtype: float64 -> uint8
# V221, range: (0.0, 384.0), dtype: float64 -> uint16
# V222, range: (0.0, 384.0), dtype: float64 -> uint16
# V223, range: (0.0, 16.0), dtype: float64 -> uint8
# V224, range: (0.0, 144.0), dtype: float64 -> uint8
# V225, range: (0.0, 51.0), dtype: float64 -> uint8
# V226, range: (0.0, 242.0), dtype: float64 -> uint8
# V227, range: (0.0, 360.0), dtype: float64 -> uint16
# V228, range: (0.0, 54.0), dtype: float64 -> uint8
# V229, range: (0.0, 176.0), dtype: float64 -> uint8
# V230, range: (0.0, 65.0), dtype: float64 -> uint8
# V231, range: (0.0, 293.0), dtype: float64 -> uint16
# V232, range: (0.0, 337.0), dtype: float64 -> uint16
# V233, range: (0.0, 332.0), dtype: float64 -> uint16
# V234, range: (0.0, 121.0), dtype: float64 -> uint8
# V235, range: (0.0, 23.0), dtype: float64 -> uint8
# V236, range: (0.0, 45.0), dtype: float64 -> uint8
# V237, range: (0.0, 39.0), dtype: float64 -> uint8
# V238, range: (0.0, 23.0), dtype: float64 -> uint8
# V239, range: (0.0, 23.0), dtype: float64 -> uint8
# V240, range: (0.0, 7.0), dtype: float64 -> uint8
# V241, range: (0.0, 5.0), dtype: float64 -> uint8
# V242, range: (0.0, 20.0), dtype: float64 -> uint8
# V243, range: (0.0, 57.0), dtype: float64 -> uint8
# V244, range: (0.0, 22.0), dtype: float64 -> uint8
# V245, range: (0.0, 262.0), dtype: float64 -> uint16
# V246, range: (0.0, 45.0), dtype: float64 -> uint8
# V247, range: (0.0, 18.0), dtype: float64 -> uint8
# V248, range: (0.0, 36.0), dtype: float64 -> uint8
# V249, range: (0.0, 22.0), dtype: float64 -> uint8
# V250, range: (0.0, 18.0), dtype: float64 -> uint8
# V251, range: (0.0, 18.0), dtype: float64 -> uint8
# V252, range: (0.0, 24.0), dtype: float64 -> uint8
# V253, range: (0.0, 163.0), dtype: float64 -> uint8
# V254, range: (0.0, 60.0), dtype: float64 -> uint8
# V255, range: (0.0, 87.0), dtype: float64 -> uint8
# V256, range: (0.0, 87.0), dtype: float64 -> uint8
# V257, range: (0.0, 48.0), dtype: float64 -> uint8
# V258, range: (0.0, 66.0), dtype: float64 -> uint8
# V259, range: (0.0, 285.0), dtype: float64 -> uint16
# V260, range: (0.0, 8.0), dtype: float64 -> uint8
# V261, range: (0.0, 49.0), dtype: float64 -> uint8
# V262, range: (0.0, 20.0), dtype: float64 -> uint8
# V263, range: (0.0, 153600.0), dtype: float64 -> float32
# V264, range: (0.0, 153600.0), dtype: float64 -> float32
# V265, range: (0.0, 153600.0), dtype: float64 -> float32
# V266, range: (0.0, 55125.0), dtype: float64 -> float32
# V267, range: (0.0, 55125.0), dtype: float64 -> float32
# V268, range: (0.0, 55125.0), dtype: float64 -> float32
# V269, range: (0.0, 55125.0), dtype: float64 -> float32
# V270, range: (0.0, 4000.0), dtype: float64 -> float32
# V271, range: (0.0, 4000.0), dtype: float64 -> float32
# V272, range: (0.0, 4000.0), dtype: float64 -> float32
# V273, range: (0.0, 51200.0), dtype: float64 -> float32
# V274, range: (0.0, 66000.0), dtype: float64 -> float32
# V275, range: (0.0, 51200.0), dtype: float64 -> float32
# V276, range: (0.0, 104060.0), dtype: float64 -> float32
# V277, range: (0.0, 104060.0), dtype: float64 -> float32
# V278, range: (0.0, 104060.0), dtype: float64 -> float32
# V279, range: (0.0, 880.0), dtype: float64 -> uint16
# V280, range: (0.0, 975.0), dtype: float64 -> uint16
# V281, range: (0.0, 22.0), dtype: float64 -> uint8
# V282, range: (0.0, 32.0), dtype: float64 -> uint8
# V283, range: (0.0, 68.0), dtype: float64 -> uint8
# V284, range: (0.0, 12.0), dtype: float64 -> uint8
# V285, range: (0.0, 95.0), dtype: float64 -> uint8
# V286, range: (0.0, 8.0), dtype: float64 -> uint8
# V287, range: (0.0, 31.0), dtype: float64 -> uint8
# V288, range: (0.0, 10.0), dtype: float64 -> uint8
# V289, range: (0.0, 12.0), dtype: float64 -> uint8
# V290, range: (1.0, 67.0), dtype: float64 -> uint8
# V291, range: (1.0, 1055.0), dtype: float64 -> uint16
# V292, range: (1.0, 323.0), dtype: float64 -> uint16
# V293, range: (0.0, 869.0), dtype: float64 -> uint16
# V294, range: (0.0, 1286.0), dtype: float64 -> uint16
# V295, range: (0.0, 928.0), dtype: float64 -> uint16
# V296, range: (0.0, 93.0), dtype: float64 -> uint8
# V297, range: (0.0, 12.0), dtype: float64 -> uint8
# V298, range: (0.0, 93.0), dtype: float64 -> uint8
# V299, range: (0.0, 49.0), dtype: float64 -> uint8
# V300, range: (0.0, 11.0), dtype: float64 -> uint8
# V301, range: (0.0, 13.0), dtype: float64 -> uint8
# V302, range: (0.0, 16.0), dtype: float64 -> uint8
# V303, range: (0.0, 20.0), dtype: float64 -> uint8
# V304, range: (0.0, 16.0), dtype: float64 -> uint8
# V305, range: (1.0, 2.0), dtype: float64 -> uint8
# V306, range: (0.0, 108800.0), dtype: float64 -> float32
# V307, range: (0.0, 145765.0), dtype: float64 -> float32
# V308, range: (0.0, 108800.0), dtype: float64 -> float32
# V309, range: (0.0, 55125.0), dtype: float64 -> float32
# V310, range: (0.0, 55125.0), dtype: float64 -> float32
# V311, range: (0.0, 55125.0), dtype: float64 -> float32
# V312, range: (0.0, 55125.0), dtype: float64 -> float32
# V313, range: (0.0, 4817.47021484375), dtype: float64 -> float32
# V314, range: (0.0, 7519.8701171875), dtype: float64 -> float32
# V315, range: (0.0, 4817.47021484375), dtype: float64 -> float32
# V316, range: (0.0, 93736.0), dtype: float64 -> float32
# V317, range: (0.0, 134021.0), dtype: float64 -> float32
# V318, range: (0.0, 98476.0), dtype: float64 -> float32
# V319, range: (0.0, 104060.0), dtype: float64 -> float32
# V320, range: (0.0, 104060.0), dtype: float64 -> float32
# V321, range: (0.0, 104060.0), dtype: float64 -> float32
# V322, range: (0.0, 880.0), dtype: float64 -> uint16
# V323, range: (0.0, 1411.0), dtype: float64 -> uint16
# V324, range: (0.0, 976.0), dtype: float64 -> uint16
# V325, range: (0.0, 12.0), dtype: float64 -> uint8
# V326, range: (0.0, 44.0), dtype: float64 -> uint8
# V327, range: (0.0, 18.0), dtype: float64 -> uint8
# V328, range: (0.0, 15.0), dtype: float64 -> uint8
# V329, range: (0.0, 99.0), dtype: float64 -> uint8
# V330, range: (0.0, 55.0), dtype: float64 -> uint8
# V331, range: (0.0, 160000.0), dtype: float64 -> float32
# V332, range: (0.0, 160000.0), dtype: float64 -> float32
# V333, range: (0.0, 160000.0), dtype: float64 -> float32
# V334, range: (0.0, 55125.0), dtype: float64 -> float32
# V335, range: (0.0, 55125.0), dtype: float64 -> float32
# V336, range: (0.0, 55125.0), dtype: float64 -> float32
# V337, range: (0.0, 104060.0), dtype: float64 -> float32
# V338, range: (0.0, 104060.0), dtype: float64 -> float32
# V339, range: (0.0, 104060.0), dtype: float64 -> float32
# id_01, range: (-100.0, 0.0), dtype: float64 -> int8
# id_02, range: (1.0, 999595.0), dtype: float64 -> uint32
# id_03, range: (-13.0, 10.0), dtype: float64 -> int8
# id_04, range: (-28.0, 0.0), dtype: float64 -> int8
# id_05, range: (-72.0, 52.0), dtype: float64 -> int8
# id_06, range: (-100.0, 0.0), dtype: float64 -> int8
# id_07, range: (-46.0, 61.0), dtype: float64 -> int8
# id_08, range: (-100.0, 0.0), dtype: float64 -> int8
# id_09, range: (-36.0, 25.0), dtype: float64 -> int8
# id_10, range: (-100.0, 0.0), dtype: float64 -> int8
# id_11, range: (90.0, 100.0), dtype: float64 -> float32
# id_13, range: (10.0, 64.0), dtype: float64 -> uint8
# id_14, range: (-660.0, 720.0), dtype: float64 -> int16
# id_17, range: (100.0, 229.0), dtype: float64 -> uint8
# id_18, range: (10.0, 29.0), dtype: float64 -> uint8
# id_19, range: (100.0, 671.0), dtype: float64 -> uint16
# id_20, range: (100.0, 661.0), dtype: float64 -> uint16
# id_21, range: (100.0, 854.0), dtype: float64 -> uint16
# id_22, range: (10.0, 44.0), dtype: float64 -> uint8
# id_24, range: (11.0, 26.0), dtype: float64 -> uint8
# id_25, range: (100.0, 548.0), dtype: float64 -> uint16
# id_26, range: (100.0, 216.0), dtype: float64 -> uint8
# id_32, range: (0.0, 32.0), dtype: float64 -> uint8
# Cents, range: (0, 999), dtype: uint16 -> uint16
# Hour, range: (0, 23), dtype: int64 -> uint8
# DayOfWeek, range: (0, 6), dtype: int64 -> uint8
# DayOfMonth, range: (1, 31), dtype: int64 -> uint8
# MonthFraction, range: (3, 100), dtype: uint8 -> uint8
# isDecember, range: (False, True), dtype: bool -> uint8
# card1__addr1_count, range: (1, 21461), dtype: int64 -> uint16
# card1__card5_count, range: (1, 26121), dtype: int64 -> uint16
# uuid3_count, range: (1, 21360), dtype: int64 -> uint16
# TransactionAmt_mean_by_uuid2_ProductCD, range: (0.615, 4545.36), dtype: float64 -> float32
# dist2_mean_by_uuid2_addr1, range: (0.0, 11623.0), dtype: float64 -> float32
# V313_mean_by_V307, range: (0.0, 4817.47021484375), dtype: float64 -> float32
# TransactionAmt_mean_by_uuid3, range: (0.588, 4545.36), dtype: float64 -> float32
# TransactionAmt_std_by_uuid3, range: (0.0, 6547.81888061895), dtype: float64 -> float32
# TransactionAmt_mean_by_uuid2, range: (0.615, 4545.36), dtype: float64 -> float32
# TransactionAmt_mean_by_uuid, range: (0.615, 4545.36), dtype: float64 -> float32
# TransactionAmt_mean_by_card1, range: (0.615, 3454.95), dtype: float64 -> float32
# card1_count, range: (1, 28015), dtype: int64 -> uint16
# card2_count, range: (123, 91731), dtype: int64 -> uint32
# card5_count, range: (1, 553537), dtype: int64 -> uint32
# addr1_count, range: (1, 131315), dtype: int64 -> uint32
# addr2_count, range: (1, 956415), dtype: int64 -> uint32
# dist1_count, range: (1, 643488), dtype: int64 -> uint32
# C1_count, range: (1, 586742), dtype: int64 -> uint32
# C2_count, range: (1, 581696), dtype: int64 -> uint32
# C5_count, range: (2, 707008), dtype: int64 -> uint32
# C6_count, range: (1, 631237), dtype: int64 -> uint32
# C7_count, range: (1, 961237), dtype: int64 -> uint32
# C9_count, range: (1, 420354), dtype: int64 -> uint32
# C11_count, range: (1, 731792), dtype: int64 -> uint32
# C13_count, range: (1, 367617), dtype: int64 -> uint32
# C14_count, range: (1, 598520), dtype: int64 -> uint32
# P_emaildomain_count, range: (80, 435803), dtype: int64 -> uint32
# DeviceInfo_count, range: (1, 863508), dtype: int64 -> uint32
# D2_na, range: (False, True), dtype: bool -> uint8
# D3_na, range: (False, True), dtype: bool -> uint8
# D5_na, range: (False, True), dtype: bool -> uint8
# D6_na, range: (False, True), dtype: bool -> uint8
# D7_na, range: (False, True), dtype: bool -> uint8
# D13_na, range: (False, True), dtype: bool -> uint8
# D14_na, range: (False, True), dtype: bool -> uint8
# M4_na, range: (False, True), dtype: bool -> uint8
# M5_na, range: (False, True), dtype: bool -> uint8
# M6_na, range: (False, True), dtype: bool -> uint8
# M7_na, range: (False, True), dtype: bool -> uint8
# M8_na, range: (False, True), dtype: bool -> uint8
# P_emaildomain_parts, range: (0, 3), dtype: int64 -> uint8
# R_emaildomain_parts, range: (0, 3), dtype: int64 -> uint8
# Browser, range: (-1, 6), dtype: int64 -> int8
# OS, range: (-1, 4), dtype: int64 -> int8
#
#  *** DONE ***
# Memory usage: 2196.14 -> 694.13 MB
# This is 31.61% of the initial size
# CPU times: user 1min 37s, sys: 3min 42s, total: 5min 19s
# Wall time: 2min 52s

# %%
# %%time
df_test, na_test = reduce_mem_usage(df_test)
# Out:
# TransactionDT, range: (18403224, 34214345), dtype: int64 -> uint32
# TransactionAmt, range: (0.018000000000000002, 10270.0), dtype: float64 -> float32
# card1, range: (1001, 18397), dtype: int64 -> uint16
# card2, range: (100.0, 600.0), dtype: float64 -> uint16
# card3, range: (100.0, 232.0), dtype: float64 -> uint8
# card5, range: (100.0, 237.0), dtype: float64 -> uint8
# addr1, range: (100.0, 540.0), dtype: float64 -> uint16
# addr2, range: (10.0, 102.0), dtype: float64 -> uint8
# dist1, range: (0.0, 8081.0), dtype: float64 -> uint16
# dist2, range: (0.0, 9213.0), dtype: float64 -> uint16
# C1, range: (0.0, 2950.0), dtype: float64 -> uint16
# C2, range: (0.0, 3275.0), dtype: float64 -> uint16
# C3, range: (0.0, 31.0), dtype: float64 -> uint8
# C4, range: (0.0, 1601.0), dtype: float64 -> uint16
# C5, range: (0.0, 376.0), dtype: float64 -> uint16
# C6, range: (0.0, 1601.0), dtype: float64 -> uint16
# C7, range: (0.0, 1621.0), dtype: float64 -> uint16
# C8, range: (0.0, 1005.0), dtype: float64 -> uint16
# C9, range: (0.0, 572.0), dtype: float64 -> uint16
# C10, range: (0.0, 881.0), dtype: float64 -> uint16
# C11, range: (0.0, 2234.0), dtype: float64 -> uint16
# C12, range: (0.0, 2234.0), dtype: float64 -> uint16
# C13, range: (0.0, 1562.0), dtype: float64 -> uint16
# C14, range: (0.0, 797.0), dtype: float64 -> uint16
# D1, range: (0.0, 641.0), dtype: float64 -> uint16
# D2, range: (0.0, 641.0), dtype: float64 -> uint16
# D3, range: (0.0, 1076.0), dtype: float64 -> uint16
# D4, range: (0.0, 1091.0), dtype: float64 -> uint16
# D5, range: (0.0, 1088.0), dtype: float64 -> uint16
# D6, range: (0.0, 1091.0), dtype: float64 -> uint16
# D7, range: (0.0, 1088.0), dtype: float64 -> uint16
# D8, range: (0.0, 2029.5833740234373), dtype: float64 -> float32
# D9, range: (0.0, 0.9583330154418944), dtype: float64 -> float32
# D10, range: (0.0, 1091.0), dtype: float64 -> uint16
# D11, range: (0.0, 883.0), dtype: float64 -> uint16
# D12, range: (0.0, 879.0), dtype: float64 -> uint16
# D13, range: (0.0, 1066.0), dtype: float64 -> uint16
# D14, range: (0.0, 1085.0), dtype: float64 -> uint16
# D15, range: (0.0, 1091.0), dtype: float64 -> uint16
# V1, range: (0.0, 1.0), dtype: float64 -> uint8
# V2, range: (0.0, 11.0), dtype: float64 -> uint8
# V3, range: (0.0, 11.0), dtype: float64 -> uint8
# V4, range: (0.0, 10.0), dtype: float64 -> uint8
# V5, range: (0.0, 10.0), dtype: float64 -> uint8
# V6, range: (0.0, 13.0), dtype: float64 -> uint8
# V7, range: (0.0, 13.0), dtype: float64 -> uint8
# V8, range: (0.0, 11.0), dtype: float64 -> uint8
# V9, range: (0.0, 11.0), dtype: float64 -> uint8
# V10, range: (0.0, 5.0), dtype: float64 -> uint8
# V11, range: (0.0, 7.0), dtype: float64 -> uint8
# V12, range: (0.0, 4.0), dtype: float64 -> uint8
# V13, range: (0.0, 6.0), dtype: float64 -> uint8
# V14, range: (0.0, 1.0), dtype: float64 -> uint8
# V15, range: (0.0, 13.0), dtype: float64 -> uint8
# V16, range: (0.0, 25.0), dtype: float64 -> uint8
# V17, range: (0.0, 10.0), dtype: float64 -> uint8
# V18, range: (0.0, 10.0), dtype: float64 -> uint8
# V19, range: (0.0, 13.0), dtype: float64 -> uint8
# V20, range: (0.0, 25.0), dtype: float64 -> uint8
# V21, range: (0.0, 5.0), dtype: float64 -> uint8
# V22, range: (0.0, 7.0), dtype: float64 -> uint8
# V23, range: (0.0, 15.0), dtype: float64 -> uint8
# V24, range: (0.0, 29.0), dtype: float64 -> uint8
# V25, range: (0.0, 13.0), dtype: float64 -> uint8
# V26, range: (0.0, 25.0), dtype: float64 -> uint8
# V27, range: (0.0, 7.0), dtype: float64 -> uint8
# V28, range: (0.0, 7.0), dtype: float64 -> uint8
# V29, range: (0.0, 4.0), dtype: float64 -> uint8
# V30, range: (0.0, 7.0), dtype: float64 -> uint8
# V31, range: (0.0, 13.0), dtype: float64 -> uint8
# V32, range: (0.0, 25.0), dtype: float64 -> uint8
# V33, range: (0.0, 13.0), dtype: float64 -> uint8
# V34, range: (0.0, 25.0), dtype: float64 -> uint8
# V35, range: (0.0, 4.0), dtype: float64 -> uint8
# V36, range: (0.0, 6.0), dtype: float64 -> uint8
# V37, range: (0.0, 49.0), dtype: float64 -> uint8
# V38, range: (0.0, 52.0), dtype: float64 -> uint8
# V39, range: (0.0, 30.0), dtype: float64 -> uint8
# V40, range: (0.0, 31.0), dtype: float64 -> uint8
# V41, range: (0.0, 1.0), dtype: float64 -> uint8
# V42, range: (0.0, 8.0), dtype: float64 -> uint8
# V43, range: (0.0, 11.0), dtype: float64 -> uint8
# V44, range: (0.0, 47.0), dtype: float64 -> uint8
# V45, range: (0.0, 69.0), dtype: float64 -> uint8
# V46, range: (0.0, 8.0), dtype: float64 -> uint8
# V47, range: (0.0, 11.0), dtype: float64 -> uint8
# V48, range: (0.0, 4.0), dtype: float64 -> uint8
# V49, range: (0.0, 7.0), dtype: float64 -> uint8
# V50, range: (0.0, 7.0), dtype: float64 -> uint8
# V51, range: (0.0, 8.0), dtype: float64 -> uint8
# V52, range: (0.0, 10.0), dtype: float64 -> uint8
# V53, range: (0.0, 5.0), dtype: float64 -> uint8
# V54, range: (0.0, 7.0), dtype: float64 -> uint8
# V55, range: (0.0, 49.0), dtype: float64 -> uint8
# V56, range: (0.0, 51.0), dtype: float64 -> uint8
# V57, range: (0.0, 6.0), dtype: float64 -> uint8
# V58, range: (0.0, 10.0), dtype: float64 -> uint8
# V59, range: (0.0, 12.0), dtype: float64 -> uint8
# V60, range: (0.0, 17.0), dtype: float64 -> uint8
# V61, range: (0.0, 6.0), dtype: float64 -> uint8
# V62, range: (0.0, 10.0), dtype: float64 -> uint8
# V63, range: (0.0, 8.0), dtype: float64 -> uint8
# V64, range: (0.0, 10.0), dtype: float64 -> uint8
# V65, range: (0.0, 1.0), dtype: float64 -> uint8
# V66, range: (0.0, 8.0), dtype: float64 -> uint8
# V67, range: (0.0, 10.0), dtype: float64 -> uint8
# V68, range: (0.0, 7.0), dtype: float64 -> uint8
# V69, range: (0.0, 4.0), dtype: float64 -> uint8
# V70, range: (0.0, 8.0), dtype: float64 -> uint8
# V71, range: (0.0, 6.0), dtype: float64 -> uint8
# V72, range: (0.0, 10.0), dtype: float64 -> uint8
# V73, range: (0.0, 8.0), dtype: float64 -> uint8
# V74, range: (0.0, 10.0), dtype: float64 -> uint8
# V75, range: (0.0, 5.0), dtype: float64 -> uint8
# V76, range: (0.0, 7.0), dtype: float64 -> uint8
# V77, range: (0.0, 80.0), dtype: float64 -> uint8
# V78, range: (0.0, 80.0), dtype: float64 -> uint8
# V79, range: (0.0, 7.0), dtype: float64 -> uint8
# V80, range: (0.0, 18.0), dtype: float64 -> uint8
# V81, range: (0.0, 18.0), dtype: float64 -> uint8
# V82, range: (0.0, 5.0), dtype: float64 -> uint8
# V83, range: (0.0, 7.0), dtype: float64 -> uint8
# V84, range: (0.0, 10.0), dtype: float64 -> uint8
# V85, range: (0.0, 10.0), dtype: float64 -> uint8
# V86, range: (0.0, 80.0), dtype: float64 -> uint8
# V87, range: (0.0, 80.0), dtype: float64 -> uint8
# V88, range: (0.0, 1.0), dtype: float64 -> uint8
# V89, range: (0.0, 7.0), dtype: float64 -> uint8
# V90, range: (0.0, 4.0), dtype: float64 -> uint8
# V91, range: (0.0, 8.0), dtype: float64 -> uint8
# V92, range: (0.0, 6.0), dtype: float64 -> uint8
# V93, range: (0.0, 7.0), dtype: float64 -> uint8
# V94, range: (0.0, 2.0), dtype: float64 -> uint8
# V95, range: (0.0, 60.0), dtype: float64 -> uint8
# V96, range: (0.0, 103.0), dtype: float64 -> uint8
# V97, range: (0.0, 82.0), dtype: float64 -> uint8
# V98, range: (0.0, 8.0), dtype: float64 -> uint8
# V99, range: (0.0, 62.0), dtype: float64 -> uint8
# V100, range: (0.0, 30.0), dtype: float64 -> uint8
# V101, range: (0.0, 18.0), dtype: float64 -> uint8
# V102, range: (0.0, 68.0), dtype: float64 -> uint8
# V103, range: (0.0, 29.0), dtype: float64 -> uint8
# V104, range: (0.0, 59.0), dtype: float64 -> uint8
# V105, range: (0.0, 99.0), dtype: float64 -> uint8
# V106, range: (0.0, 80.0), dtype: float64 -> uint8
# V107, range: (1.0, 1.0), dtype: float64 -> uint8
# V108, range: (0.0, 8.0), dtype: float64 -> uint8
# V109, range: (0.0, 8.0), dtype: float64 -> uint8
# V110, range: (0.0, 8.0), dtype: float64 -> uint8
# V111, range: (0.0, 8.0), dtype: float64 -> uint8
# V112, range: (0.0, 8.0), dtype: float64 -> uint8
# V113, range: (0.0, 8.0), dtype: float64 -> uint8
# V114, range: (0.0, 9.0), dtype: float64 -> uint8
# V115, range: (0.0, 9.0), dtype: float64 -> uint8
# V116, range: (0.0, 9.0), dtype: float64 -> uint8
# V117, range: (0.0, 2.0), dtype: float64 -> uint8
# V118, range: (0.0, 3.0), dtype: float64 -> uint8
# V119, range: (0.0, 2.0), dtype: float64 -> uint8
# V120, range: (0.0, 4.0), dtype: float64 -> uint8
# V121, range: (0.0, 4.0), dtype: float64 -> uint8
# V122, range: (0.0, 4.0), dtype: float64 -> uint8
# V123, range: (0.0, 12.0), dtype: float64 -> uint8
# V124, range: (0.0, 13.0), dtype: float64 -> uint8
# V125, range: (0.0, 12.0), dtype: float64 -> uint8
# V126, range: (0.0, 519038.5), dtype: float64 -> float32
# V127, range: (0.0, 544500.0), dtype: float64 -> float32
# V128, range: (0.0, 519038.5), dtype: float64 -> float32
# V129, range: (0.0, 64800.0), dtype: float64 -> float32
# V130, range: (0.0, 167200.0), dtype: float64 -> float32
# V131, range: (0.0, 167200.0), dtype: float64 -> float32
# V132, range: (0.0, 519038.5), dtype: float64 -> float32
# V133, range: (0.0, 519038.5), dtype: float64 -> float32
# V134, range: (0.0, 519038.5), dtype: float64 -> float32
# V135, range: (0.0, 302500.0), dtype: float64 -> float32
# V136, range: (0.0, 302500.0), dtype: float64 -> float32
# V137, range: (0.0, 302500.0), dtype: float64 -> float32
# V138, range: (0.0, 20.0), dtype: float64 -> uint8
# V139, range: (0.0, 28.0), dtype: float64 -> uint8
# V140, range: (0.0, 59.0), dtype: float64 -> uint8
# V141, range: (0.0, 6.0), dtype: float64 -> uint8
# V142, range: (0.0, 11.0), dtype: float64 -> uint8
# V143, range: (0.0, 56.0), dtype: float64 -> uint8
# V144, range: (0.0, 85.0), dtype: float64 -> uint8
# V145, range: (0.0, 279.0), dtype: float64 -> uint16
# V146, range: (0.0, 12.0), dtype: float64 -> uint8
# V147, range: (0.0, 22.0), dtype: float64 -> uint8
# V148, range: (0.0, 11.0), dtype: float64 -> uint8
# V149, range: (0.0, 11.0), dtype: float64 -> uint8
# V150, range: (1.0, 2277.0), dtype: float64 -> uint16
# V151, range: (1.0, 58.0), dtype: float64 -> uint8
# V152, range: (1.0, 67.0), dtype: float64 -> uint8
# V153, range: (0.0, 8.0), dtype: float64 -> uint8
# V154, range: (0.0, 9.0), dtype: float64 -> uint8
# V155, range: (0.0, 11.0), dtype: float64 -> uint8
# V156, range: (0.0, 11.0), dtype: float64 -> uint8
# V157, range: (0.0, 13.0), dtype: float64 -> uint8
# V158, range: (0.0, 13.0), dtype: float64 -> uint8
# V159, range: (0.0, 284129.8125), dtype: float64 -> float32
# V160, range: (0.0, 3867868.5), dtype: float64 -> float32
# V161, range: (0.0, 2000.0), dtype: float64 -> float32
# V162, range: (0.0, 4000.0), dtype: float64 -> float32
# V163, range: (0.0, 4000.0), dtype: float64 -> float32
# V164, range: (0.0, 928882.0), dtype: float64 -> float32
# V165, range: (0.0, 928882.0), dtype: float64 -> float32
# V166, range: (0.0, 453750.0), dtype: float64 -> float32
# V167, range: (0.0, 238.0), dtype: float64 -> uint8
# V168, range: (0.0, 257.0), dtype: float64 -> uint16
# V169, range: (0.0, 39.0), dtype: float64 -> uint8
# V170, range: (0.0, 63.0), dtype: float64 -> uint8
# V171, range: (0.0, 68.0), dtype: float64 -> uint8
# V172, range: (0.0, 37.0), dtype: float64 -> uint8
# V173, range: (0.0, 9.0), dtype: float64 -> uint8
# V174, range: (0.0, 6.0), dtype: float64 -> uint8
# V175, range: (0.0, 22.0), dtype: float64 -> uint8
# V176, range: (1.0, 239.0), dtype: float64 -> uint8
# V177, range: (0.0, 238.0), dtype: float64 -> uint8
# V178, range: (0.0, 257.0), dtype: float64 -> uint16
# V179, range: (0.0, 257.0), dtype: float64 -> uint16
# V180, range: (0.0, 179.0), dtype: float64 -> uint8
# V181, range: (0.0, 85.0), dtype: float64 -> uint8
# V182, range: (0.0, 125.0), dtype: float64 -> uint8
# V183, range: (0.0, 106.0), dtype: float64 -> uint8
# V184, range: (0.0, 12.0), dtype: float64 -> uint8
# V185, range: (0.0, 12.0), dtype: float64 -> uint8
# V186, range: (0.0, 39.0), dtype: float64 -> uint8
# V187, range: (0.0, 158.0), dtype: float64 -> uint8
# V188, range: (0.0, 44.0), dtype: float64 -> uint8
# V189, range: (0.0, 44.0), dtype: float64 -> uint8
# V190, range: (0.0, 224.0), dtype: float64 -> uint8
# V191, range: (0.0, 20.0), dtype: float64 -> uint8
# V192, range: (0.0, 37.0), dtype: float64 -> uint8
# V193, range: (0.0, 32.0), dtype: float64 -> uint8
# V194, range: (0.0, 7.0), dtype: float64 -> uint8
# V195, range: (0.0, 18.0), dtype: float64 -> uint8
# V196, range: (0.0, 41.0), dtype: float64 -> uint8
# V197, range: (0.0, 11.0), dtype: float64 -> uint8
# V198, range: (0.0, 29.0), dtype: float64 -> uint8
# V199, range: (0.0, 224.0), dtype: float64 -> uint8
# V200, range: (0.0, 47.0), dtype: float64 -> uint8
# V201, range: (0.0, 47.0), dtype: float64 -> uint8
# V202, range: (0.0, 1065496.5), dtype: float64 -> float32
# V203, range: (0.0, 1065496.5), dtype: float64 -> float32
# V204, range: (0.0, 1065496.5), dtype: float64 -> float32
# V205, range: (0.0, 64800.0), dtype: float64 -> float32
# V206, range: (0.0, 64800.0), dtype: float64 -> float32
# V207, range: (0.0, 167200.0), dtype: float64 -> float32
# V208, range: (0.0, 4000.0), dtype: float64 -> float32
# V209, range: (0.0, 10000.0), dtype: float64 -> float32
# V210, range: (0.0, 4000.0), dtype: float64 -> float32
# V211, range: (0.0, 928882.0), dtype: float64 -> float32
# V212, range: (0.0, 958320.0), dtype: float64 -> float32
# V213, range: (0.0, 928882.0), dtype: float64 -> float32
# V214, range: (0.0, 453750.0), dtype: float64 -> float32
# V215, range: (0.0, 756250.0), dtype: float64 -> float32
# V216, range: (0.0, 756250.0), dtype: float64 -> float32
# V217, range: (0.0, 238.0), dtype: float64 -> uint8
# V218, range: (0.0, 290.0), dtype: float64 -> uint16
# V219, range: (0.0, 290.0), dtype: float64 -> uint16
# V220, range: (0.0, 47.0), dtype: float64 -> uint8
# V221, range: (0.0, 140.0), dtype: float64 -> uint8
# V222, range: (0.0, 291.0), dtype: float64 -> uint16
# V223, range: (0.0, 11.0), dtype: float64 -> uint8
# V224, range: (0.0, 91.0), dtype: float64 -> uint8
# V225, range: (0.0, 58.0), dtype: float64 -> uint8
# V226, range: (0.0, 870.0), dtype: float64 -> uint16
# V227, range: (0.0, 131.0), dtype: float64 -> uint8
# V228, range: (1.0, 239.0), dtype: float64 -> uint8
# V229, range: (1.0, 262.0), dtype: float64 -> uint16
# V230, range: (1.0, 262.0), dtype: float64 -> uint16
# V231, range: (0.0, 238.0), dtype: float64 -> uint8
# V232, range: (0.0, 290.0), dtype: float64 -> uint16
# V233, range: (0.0, 290.0), dtype: float64 -> uint16
# V234, range: (0.0, 322.0), dtype: float64 -> uint16
# V235, range: (0.0, 18.0), dtype: float64 -> uint8
# V236, range: (0.0, 57.0), dtype: float64 -> uint8
# V237, range: (0.0, 31.0), dtype: float64 -> uint8
# V238, range: (0.0, 12.0), dtype: float64 -> uint8
# V239, range: (0.0, 12.0), dtype: float64 -> uint8
# V240, range: (1.0, 6.0), dtype: float64 -> uint8
# V241, range: (1.0, 3.0), dtype: float64 -> uint8
# V242, range: (0.0, 27.0), dtype: float64 -> uint8
# V243, range: (0.0, 54.0), dtype: float64 -> uint8
# V244, range: (0.0, 33.0), dtype: float64 -> uint8
# V245, range: (0.0, 124.0), dtype: float64 -> uint8
# V246, range: (0.0, 224.0), dtype: float64 -> uint8
# V247, range: (0.0, 11.0), dtype: float64 -> uint8
# V248, range: (0.0, 29.0), dtype: float64 -> uint8
# V249, range: (0.0, 19.0), dtype: float64 -> uint8
# V250, range: (0.0, 8.0), dtype: float64 -> uint8
# V251, range: (0.0, 12.0), dtype: float64 -> uint8
# V252, range: (0.0, 21.0), dtype: float64 -> uint8
# V253, range: (0.0, 96.0), dtype: float64 -> uint8
# V254, range: (0.0, 39.0), dtype: float64 -> uint8
# V255, range: (0.0, 53.0), dtype: float64 -> uint8
# V256, range: (0.0, 53.0), dtype: float64 -> uint8
# V257, range: (0.0, 224.0), dtype: float64 -> uint8
# V258, range: (0.0, 269.0), dtype: float64 -> uint16
# V259, range: (0.0, 131.0), dtype: float64 -> uint8
# V260, range: (0.0, 14.0), dtype: float64 -> uint8
# V261, range: (0.0, 89.0), dtype: float64 -> uint8
# V262, range: (0.0, 34.0), dtype: float64 -> uint8
# V263, range: (0.0, 1065496.5), dtype: float64 -> float32
# V264, range: (0.0, 1065496.5), dtype: float64 -> float32
# V265, range: (0.0, 1065496.5), dtype: float64 -> float32
# V266, range: (0.0, 64800.0), dtype: float64 -> float32
# V267, range: (0.0, 64800.0), dtype: float64 -> float32
# V268, range: (0.0, 64800.0), dtype: float64 -> float32
# V269, range: (0.0, 64800.0), dtype: float64 -> float32
# V270, range: (0.0, 10791.5703125), dtype: float64 -> float32
# V271, range: (0.0, 10791.5703125), dtype: float64 -> float32
# V272, range: (0.0, 10791.5703125), dtype: float64 -> float32
# V273, range: (0.0, 928882.0), dtype: float64 -> float32
# V274, range: (0.0, 928882.0), dtype: float64 -> float32
# V275, range: (0.0, 928882.0), dtype: float64 -> float32
# V276, range: (0.0, 453750.0), dtype: float64 -> float32
# V277, range: (0.0, 756250.0), dtype: float64 -> float32
# V278, range: (0.0, 756250.0), dtype: float64 -> float32
# V279, range: (0.0, 86.0), dtype: float64 -> uint8
# V280, range: (0.0, 108.0), dtype: float64 -> uint8
# V281, range: (0.0, 30.0), dtype: float64 -> uint8
# V282, range: (0.0, 63.0), dtype: float64 -> uint8
# V283, range: (0.0, 68.0), dtype: float64 -> uint8
# V284, range: (0.0, 8.0), dtype: float64 -> uint8
# V285, range: (0.0, 90.0), dtype: float64 -> uint8
# V286, range: (0.0, 6.0), dtype: float64 -> uint8
# V287, range: (0.0, 31.0), dtype: float64 -> uint8
# V288, range: (0.0, 6.0), dtype: float64 -> uint8
# V289, range: (0.0, 11.0), dtype: float64 -> uint8
# V290, range: (1.0, 49.0), dtype: float64 -> uint8
# V291, range: (1.0, 250.0), dtype: float64 -> uint8
# V292, range: (1.0, 75.0), dtype: float64 -> uint8
# V293, range: (0.0, 62.0), dtype: float64 -> uint8
# V294, range: (0.0, 246.0), dtype: float64 -> uint8
# V295, range: (0.0, 78.0), dtype: float64 -> uint8
# V296, range: (0.0, 179.0), dtype: float64 -> uint8
# V297, range: (0.0, 85.0), dtype: float64 -> uint8
# V298, range: (0.0, 125.0), dtype: float64 -> uint8
# V299, range: (0.0, 106.0), dtype: float64 -> uint8
# V300, range: (0.0, 14.0), dtype: float64 -> uint8
# V301, range: (0.0, 14.0), dtype: float64 -> uint8
# V302, range: (0.0, 13.0), dtype: float64 -> uint8
# V303, range: (0.0, 17.0), dtype: float64 -> uint8
# V304, range: (0.0, 17.0), dtype: float64 -> uint8
# V305, range: (1.0, 2.0), dtype: float64 -> uint8
# V306, range: (0.0, 718740.0), dtype: float64 -> float32
# V307, range: (0.0, 958320.0), dtype: float64 -> float32
# V308, range: (0.0, 718740.0), dtype: float64 -> float32
# V309, range: (0.0, 64800.0), dtype: float64 -> float32
# V310, range: (0.0, 167200.0), dtype: float64 -> float32
# V311, range: (0.0, 64800.0), dtype: float64 -> float32
# V312, range: (0.0, 167200.0), dtype: float64 -> float32
# V313, range: (0.0, 4727.9599609375), dtype: float64 -> float32
# V314, range: (0.0, 7539.75), dtype: float64 -> float32
# V315, range: (0.0, 4727.9599609375), dtype: float64 -> float32
# V316, range: (0.0, 718740.0), dtype: float64 -> float32
# V317, range: (0.0, 958320.0), dtype: float64 -> float32
# V318, range: (0.0, 718740.0), dtype: float64 -> float32
# V319, range: (0.0, 453750.0), dtype: float64 -> float32
# V320, range: (0.0, 605000.0), dtype: float64 -> float32
# V321, range: (0.0, 605000.0), dtype: float64 -> float32
# V322, range: (0.0, 86.0), dtype: float64 -> uint8
# V323, range: (0.0, 128.0), dtype: float64 -> uint8
# V324, range: (0.0, 108.0), dtype: float64 -> uint8
# V325, range: (0.0, 8.0), dtype: float64 -> uint8
# V326, range: (0.0, 44.0), dtype: float64 -> uint8
# V327, range: (0.0, 31.0), dtype: float64 -> uint8
# V328, range: (0.0, 85.0), dtype: float64 -> uint8
# V329, range: (0.0, 125.0), dtype: float64 -> uint8
# V330, range: (0.0, 106.0), dtype: float64 -> uint8
# V331, range: (0.0, 1040657.5), dtype: float64 -> float32
# V332, range: (0.0, 1040657.5), dtype: float64 -> float32
# V333, range: (0.0, 1040657.5), dtype: float64 -> float32
# V334, range: (0.0, 64800.0), dtype: float64 -> float32
# V335, range: (0.0, 64800.0), dtype: float64 -> float32
# V336, range: (0.0, 64800.0), dtype: float64 -> float32
# V337, range: (0.0, 375000.0), dtype: float64 -> float32
# V338, range: (0.0, 612500.0), dtype: float64 -> float32
# V339, range: (0.0, 612500.0), dtype: float64 -> float32
# id_01, range: (-100.0, 0.0), dtype: float64 -> int8
# id_02, range: (2.0, 999869.0), dtype: float64 -> uint32
# id_03, range: (-12.0, 11.0), dtype: float64 -> int8
# id_04, range: (-19.0, 0.0), dtype: float64 -> int8
# id_05, range: (-81.0, 52.0), dtype: float64 -> int8
# id_06, range: (-100.0, 0.0), dtype: float64 -> int8
# id_07, range: (-41.0, 59.0), dtype: float64 -> int8
# id_08, range: (-100.0, 0.0), dtype: float64 -> int8
# id_09, range: (-32.0, 16.0), dtype: float64 -> int8
# id_10, range: (-100.0, 0.0), dtype: float64 -> int8
# id_11, range: (90.0, 100.0), dtype: float64 -> float32
# id_13, range: (11.0, 63.0), dtype: float64 -> uint8
# id_14, range: (-720.0, 720.0), dtype: float64 -> int16
# id_17, range: (100.0, 228.0), dtype: float64 -> uint8
# id_18, range: (11.0, 29.0), dtype: float64 -> uint8
# id_19, range: (100.0, 670.0), dtype: float64 -> uint16
# id_20, range: (100.0, 660.0), dtype: float64 -> uint16
# id_21, range: (100.0, 854.0), dtype: float64 -> uint16
# id_22, range: (11.0, 44.0), dtype: float64 -> uint8
# id_24, range: (10.0, 26.0), dtype: float64 -> uint8
# id_25, range: (100.0, 549.0), dtype: float64 -> uint16
# id_26, range: (100.0, 216.0), dtype: float64 -> uint8
# id_32, range: (8.0, 48.0), dtype: float64 -> uint8
# Cents, range: (0, 999), dtype: uint16 -> uint16
# Hour, range: (0, 23), dtype: int64 -> uint8
# DayOfWeek, range: (0, 6), dtype: int64 -> uint8
# DayOfMonth, range: (1, 31), dtype: int64 -> uint8
# MonthFraction, range: (3, 100), dtype: uint8 -> uint8
# isDecember, range: (False, True), dtype: bool -> uint8
# card1__addr1_count, range: (1, 21461), dtype: int64 -> uint16
# card1__card5_count, range: (1, 26121), dtype: int64 -> uint16
# uuid3_count, range: (1, 21360), dtype: int64 -> uint16
# TransactionAmt_mean_by_uuid2_ProductCD, range: (1.4669999999999999, 6237.45), dtype: float64 -> float32
# dist2_mean_by_uuid2_addr1, range: (0.0, 8145.0), dtype: float64 -> float32
# V313_mean_by_V307, range: (0.0, 4727.9599609375), dtype: float64 -> float32
# TransactionAmt_mean_by_uuid3, range: (1.4669999999999999, 6237.45), dtype: float64 -> float32
# TransactionAmt_std_by_uuid3, range: (0.0, 3334.715580075758), dtype: float64 -> float32
# TransactionAmt_mean_by_uuid2, range: (2.6460000000000004, 4327.02), dtype: float64 -> float32
# TransactionAmt_mean_by_uuid, range: (2.6460000000000004, 4327.02), dtype: float64 -> float32
# TransactionAmt_mean_by_card1, range: (2.6460000000000004, 4327.02), dtype: float64 -> float32
# card1_count, range: (1, 28015), dtype: int64 -> uint16
# card2_count, range: (123, 91731), dtype: int64 -> uint32
# card5_count, range: (1, 553537), dtype: int64 -> uint32
# addr1_count, range: (1, 131315), dtype: int64 -> uint32
# addr2_count, range: (1, 956415), dtype: int64 -> uint32
# dist1_count, range: (1, 643488), dtype: int64 -> uint32
# C1_count, range: (1, 586742), dtype: int64 -> uint32
# C2_count, range: (1, 581696), dtype: int64 -> uint32
# C5_count, range: (1, 707008), dtype: int64 -> uint32
# C6_count, range: (1, 631237), dtype: int64 -> uint32
# C7_count, range: (1, 961237), dtype: int64 -> uint32
# C9_count, range: (1, 420354), dtype: int64 -> uint32
# C11_count, range: (1, 731792), dtype: int64 -> uint32
# C13_count, range: (1, 367617), dtype: int64 -> uint32
# C14_count, range: (1, 598520), dtype: int64 -> uint32
# P_emaildomain_count, range: (2, 435803), dtype: int64 -> uint32
# DeviceInfo_count, range: (1, 863508), dtype: int64 -> uint32
# D2_na, range: (False, True), dtype: bool -> uint8
# D3_na, range: (False, True), dtype: bool -> uint8
# D5_na, range: (False, True), dtype: bool -> uint8
# D6_na, range: (False, True), dtype: bool -> uint8
# D7_na, range: (False, True), dtype: bool -> uint8
# D13_na, range: (False, True), dtype: bool -> uint8
# D14_na, range: (False, True), dtype: bool -> uint8
# M4_na, range: (False, True), dtype: bool -> uint8
# M5_na, range: (False, True), dtype: bool -> uint8
# M6_na, range: (False, True), dtype: bool -> uint8
# M7_na, range: (False, True), dtype: bool -> uint8
# M8_na, range: (False, True), dtype: bool -> uint8
# P_emaildomain_parts, range: (0, 3), dtype: int64 -> uint8
# R_emaildomain_parts, range: (0, 3), dtype: int64 -> uint8
# Browser, range: (-1, 6), dtype: int64 -> int8
# OS, range: (-1, 4), dtype: int64 -> int8
#
#  *** DONE ***
# Memory usage: 1883.29 -> 588.75 MB
# This is 31.26% of the initial size
# CPU times: user 1min 28s, sys: 3min 7s, total: 4min 36s
# Wall time: 2min 29s

# %%
y_train, df_train = split_label_inputs(df_train)
df_train.shape, y_train.shape
# Out:
# ((590540, 494), (590540,))

# %%
all_dfs = [df_train, df_test]

for col in ['card4', 'card6', 'ProductCD', 'M4']:
    print('Encoding', col)
    temp_df = pd.concat([df[col] for df in all_dfs])
    col_encoded = temp_df.value_counts().to_dict()
    del temp_df
    for df in all_dfs:
        df[col] = df[col].map(col_encoded)
    print(col_encoded)
# Out:
# Encoding card4
# {'visa': 719649, 'mastercard': 347386, 'american express': 16009, 'discover': 9524}
# Encoding card6
# {'debit': 824959, 'credit': 267648, 'debit or credit': 30, 'charge card': 16}
# Encoding ProductCD
# {'W': 800657, 'C': 137785, 'R': 73346, 'H': 62397, 'S': 23046}
# Encoding M4
# {'M0': 357789, 'M2': 122947, 'M1': 97306}

# %%
for col in ['M1','M2','M3','M5','M6','M7','M8','M9']:
    for df in all_dfs:
        df[col] = df[col].map({ 'T': 1, 'F': 0 })

# %%
def minify_identity_df(df):
    df['id_23'] = df['id_23'].map({
        'TRANSPARENT': 4, 
        'IP_PROXY': 3, 
        'IP_PROXY:ANONYMOUS': 2, 
        'IP_PROXY:HIDDEN': 1
    })
    
    for col in ['id_16']:
        df[col+'_na'] = df[col].isna()
    
    for col in ['id_12', 'id_15', 'id_16', 'id_27', 'id_28', 'id_29']:
        df[col] = df[col].map({
            'New': 2, 
            'Found': 1, 
            'NotFound': 0, 
            'Unknown': -1
        })

    for col in ['id_35', 'id_36', 'id_37', 'id_38']:
        df[col] = df[col].map({ 'T': 1, 'F': 0 })

    df['id_34'] = df['id_34'].fillna(':-2')
    df['id_34'] = df['id_34'].apply(lambda x: x.split(':')[1]).astype(np.int8)
    df['id_34'] = np.where(df['id_34'] == -2, np.nan, df['id_34'])
    
    df['id_33'] = df['id_33'].fillna('0x0')
    df['id_33_0'] = df['id_33'].apply(lambda x: x.split('x')[0]).astype(int)
    df['id_33_1'] = df['id_33'].apply(lambda x: x.split('x')[1]).astype(int)
    df['id_33'] = np.where(df['id_33'] == '0x0', np.nan, df['id_33'])

    df['DeviceType'] = df['DeviceType'].map({ 'desktop': 1, 'mobile': 0 })
    return df

# %%
import itertools


for df in all_dfs:
    minify_identity_df(df)

for col in ['id_33', 'P_emaildomain', 'R_emaildomain', 'id_30', 'id_31', 'DeviceInfo'] + encode_labels_cols:
    for df in all_dfs:
        df[col] = df[col].fillna('unknown_value')
    
    le = LabelEncoder()
    values = [list(df[col]) for df in all_dfs]
    values = list(itertools.chain(*values))
    le.fit(values)
    
    for df in all_dfs:
        df[col] = le.transform(df[col])

# %%
drop = [COL_DT]

for df in all_dfs:  
    for col in df.columns:
        if col in drop:
            df.drop(col, axis=1, inplace=True)

# %%
df_train, na_train = reduce_mem_usage(df_train)
for df, filename in zip([df_train, na_train, y_train], 
                        ['df_train.pkl', 'na_train.pkl', 'y_train.pkl']):
    save_to_disk(df, filename)
# Out:
# TransactionAmt, range: (0.25099998712539673, 31937.390625), dtype: float32 -> float32
# ProductCD, range: (23046, 800657), dtype: int64 -> uint32
# card1, range: (1000, 18396), dtype: uint16 -> uint16
# card2, range: (100, 33314), dtype: uint16 -> uint16
# card3, range: (34, 231), dtype: uint8 -> uint8
# card4, range: (9524.0, 719649.0), dtype: float64 -> uint32
# card5, range: (34, 237), dtype: uint8 -> uint8
# card6, range: (16.0, 824959.0), dtype: float64 -> uint32
# addr1, range: (100, 33314), dtype: uint16 -> uint16
# addr2, range: (10, 102), dtype: uint8 -> uint8
# dist1, range: (0, 33314), dtype: uint16 -> uint16
# dist2, range: (0, 33314), dtype: uint16 -> uint16
# P_emaildomain, range: (0, 60), dtype: int64 -> uint8
# R_emaildomain, range: (0, 60), dtype: int64 -> uint8
# C1, range: (0, 4685), dtype: uint16 -> uint16
# C2, range: (0, 5691), dtype: uint16 -> uint16
# C3, range: (0, 26), dtype: uint8 -> uint8
# C4, range: (0, 2253), dtype: uint16 -> uint16
# C5, range: (0, 349), dtype: uint16 -> uint16
# C6, range: (0, 2253), dtype: uint16 -> uint16
# C7, range: (0, 2255), dtype: uint16 -> uint16
# C8, range: (0, 3331), dtype: uint16 -> uint16
# C9, range: (0, 210), dtype: uint8 -> uint8
# C10, range: (0, 3257), dtype: uint16 -> uint16
# C11, range: (0, 3188), dtype: uint16 -> uint16
# C12, range: (0, 3188), dtype: uint16 -> uint16
# C13, range: (0, 2918), dtype: uint16 -> uint16
# C14, range: (0, 1429), dtype: uint16 -> uint16
# D1, range: (0, 33314), dtype: uint16 -> uint16
# D2, range: (0, 33314), dtype: uint16 -> uint16
# D3, range: (0, 33314), dtype: uint16 -> uint16
# D4, range: (-32222, 869), dtype: int16 -> int16
# D5, range: (0, 33314), dtype: uint16 -> uint16
# D6, range: (-32222, 873), dtype: int16 -> int16
# D7, range: (0, 33314), dtype: uint16 -> uint16
# D8, range: (-32222.0, 1707.7916259765625), dtype: float32 -> float32
# D9, range: (-32222.0, 0.9583330154418945), dtype: float32 -> float32
# D10, range: (0, 33314), dtype: uint16 -> uint16
# D11, range: (-32222, 670), dtype: int16 -> int16
# D12, range: (-32222, 648), dtype: int16 -> int16
# D13, range: (0, 33314), dtype: uint16 -> uint16
# D14, range: (-32222, 878), dtype: int16 -> int16
# D15, range: (-32222, 879), dtype: int16 -> int16
# M1, range: (0.0, 1.0), dtype: float64 -> uint8
# M2, range: (0.0, 1.0), dtype: float64 -> uint8
# M3, range: (0.0, 1.0), dtype: float64 -> uint8
# M4, range: (97306.0, 357789.0), dtype: float64 -> uint32
# M5, range: (0.0, 1.0), dtype: float64 -> uint8
# M6, range: (0.0, 1.0), dtype: float64 -> uint8
# M7, range: (0.0, 1.0), dtype: float64 -> uint8
# M8, range: (0.0, 1.0), dtype: float64 -> uint8
# M9, range: (0.0, 1.0), dtype: float64 -> uint8
# V1, range: (0, 34), dtype: uint8 -> uint8
# V2, range: (0, 34), dtype: uint8 -> uint8
# V3, range: (0, 34), dtype: uint8 -> uint8
# V4, range: (0, 34), dtype: uint8 -> uint8
# V5, range: (0, 34), dtype: uint8 -> uint8
# V6, range: (0, 34), dtype: uint8 -> uint8
# V7, range: (0, 34), dtype: uint8 -> uint8
# V8, range: (0, 34), dtype: uint8 -> uint8
# V9, range: (0, 34), dtype: uint8 -> uint8
# V10, range: (0, 34), dtype: uint8 -> uint8
# V11, range: (0, 34), dtype: uint8 -> uint8
# V12, range: (0, 34), dtype: uint8 -> uint8
# V13, range: (0, 34), dtype: uint8 -> uint8
# V14, range: (0, 34), dtype: uint8 -> uint8
# V15, range: (0, 34), dtype: uint8 -> uint8
# V16, range: (0, 34), dtype: uint8 -> uint8
# V17, range: (0, 34), dtype: uint8 -> uint8
# V18, range: (0, 34), dtype: uint8 -> uint8
# V19, range: (0, 34), dtype: uint8 -> uint8
# V20, range: (0, 34), dtype: uint8 -> uint8
# V21, range: (0, 34), dtype: uint8 -> uint8
# V22, range: (0, 34), dtype: uint8 -> uint8
# V23, range: (0, 34), dtype: uint8 -> uint8
# V24, range: (0, 34), dtype: uint8 -> uint8
# V25, range: (0, 34), dtype: uint8 -> uint8
# V26, range: (0, 34), dtype: uint8 -> uint8
# V27, range: (0, 34), dtype: uint8 -> uint8
# V28, range: (0, 34), dtype: uint8 -> uint8
# V29, range: (0, 34), dtype: uint8 -> uint8
# V30, range: (0, 34), dtype: uint8 -> uint8
# V31, range: (0, 34), dtype: uint8 -> uint8
# V32, range: (0, 34), dtype: uint8 -> uint8
# V33, range: (0, 34), dtype: uint8 -> uint8
# V34, range: (0, 34), dtype: uint8 -> uint8
# V35, range: (0, 34), dtype: uint8 -> uint8
# V36, range: (0, 34), dtype: uint8 -> uint8
# V37, range: (0, 54), dtype: uint8 -> uint8
# V38, range: (0, 54), dtype: uint8 -> uint8
# V39, range: (0, 34), dtype: uint8 -> uint8
# V40, range: (0, 34), dtype: uint8 -> uint8
# V41, range: (0, 34), dtype: uint8 -> uint8
# V42, range: (0, 34), dtype: uint8 -> uint8
# V43, range: (0, 34), dtype: uint8 -> uint8
# V44, range: (0, 48), dtype: uint8 -> uint8
# V45, range: (0, 48), dtype: uint8 -> uint8
# V46, range: (0, 34), dtype: uint8 -> uint8
# V47, range: (0, 34), dtype: uint8 -> uint8
# V48, range: (0, 34), dtype: uint8 -> uint8
# V49, range: (0, 34), dtype: uint8 -> uint8
# V50, range: (0, 34), dtype: uint8 -> uint8
# V51, range: (0, 34), dtype: uint8 -> uint8
# V52, range: (0, 34), dtype: uint8 -> uint8
# V53, range: (0, 34), dtype: uint8 -> uint8
# V54, range: (0, 34), dtype: uint8 -> uint8
# V55, range: (0, 34), dtype: uint8 -> uint8
# V56, range: (0, 51), dtype: uint8 -> uint8
# V57, range: (0, 34), dtype: uint8 -> uint8
# V58, range: (0, 34), dtype: uint8 -> uint8
# V59, range: (0, 34), dtype: uint8 -> uint8
# V60, range: (0, 34), dtype: uint8 -> uint8
# V61, range: (0, 34), dtype: uint8 -> uint8
# V62, range: (0, 34), dtype: uint8 -> uint8
# V63, range: (0, 34), dtype: uint8 -> uint8
# V64, range: (0, 34), dtype: uint8 -> uint8
# V65, range: (0, 34), dtype: uint8 -> uint8
# V66, range: (0, 34), dtype: uint8 -> uint8
# V67, range: (0, 34), dtype: uint8 -> uint8
# V68, range: (0, 34), dtype: uint8 -> uint8
# V69, range: (0, 34), dtype: uint8 -> uint8
# V70, range: (0, 34), dtype: uint8 -> uint8
# V71, range: (0, 34), dtype: uint8 -> uint8
# V72, range: (0, 34), dtype: uint8 -> uint8
# V73, range: (0, 34), dtype: uint8 -> uint8
# V74, range: (0, 34), dtype: uint8 -> uint8
# V75, range: (0, 34), dtype: uint8 -> uint8
# V76, range: (0, 34), dtype: uint8 -> uint8
# V77, range: (0, 34), dtype: uint8 -> uint8
# V78, range: (0, 34), dtype: uint8 -> uint8
# V79, range: (0, 34), dtype: uint8 -> uint8
# V80, range: (0, 34), dtype: uint8 -> uint8
# V81, range: (0, 34), dtype: uint8 -> uint8
# V82, range: (0, 34), dtype: uint8 -> uint8
# V83, range: (0, 34), dtype: uint8 -> uint8
# V84, range: (0, 34), dtype: uint8 -> uint8
# V85, range: (0, 34), dtype: uint8 -> uint8
# V86, range: (0, 34), dtype: uint8 -> uint8
# V87, range: (0, 34), dtype: uint8 -> uint8
# V88, range: (0, 34), dtype: uint8 -> uint8
# V89, range: (0, 34), dtype: uint8 -> uint8
# V90, range: (0, 34), dtype: uint8 -> uint8
# V91, range: (0, 34), dtype: uint8 -> uint8
# V92, range: (0, 34), dtype: uint8 -> uint8
# V93, range: (0, 34), dtype: uint8 -> uint8
# V94, range: (0, 34), dtype: uint8 -> uint8
# V95, range: (0, 33314), dtype: uint16 -> uint16
# V96, range: (0, 33314), dtype: uint16 -> uint16
# V97, range: (0, 33314), dtype: uint16 -> uint16
# V98, range: (0, 34), dtype: uint8 -> uint8
# V99, range: (0, 88), dtype: uint8 -> uint8
# V100, range: (0, 34), dtype: uint8 -> uint8
# V101, range: (0, 33314), dtype: uint16 -> uint16
# V102, range: (0, 33314), dtype: uint16 -> uint16
# V103, range: (0, 33314), dtype: uint16 -> uint16
# V104, range: (0, 34), dtype: uint8 -> uint8
# V105, range: (0, 99), dtype: uint8 -> uint8
# V106, range: (0, 55), dtype: uint8 -> uint8
# V107, range: (0, 34), dtype: uint8 -> uint8
# V108, range: (0, 34), dtype: uint8 -> uint8
# V109, range: (0, 34), dtype: uint8 -> uint8
# V110, range: (0, 34), dtype: uint8 -> uint8
# V111, range: (0, 34), dtype: uint8 -> uint8
# V112, range: (0, 34), dtype: uint8 -> uint8
# V113, range: (0, 34), dtype: uint8 -> uint8
# V114, range: (0, 34), dtype: uint8 -> uint8
# V115, range: (0, 34), dtype: uint8 -> uint8
# V116, range: (0, 34), dtype: uint8 -> uint8
# V117, range: (0, 34), dtype: uint8 -> uint8
# V118, range: (0, 34), dtype: uint8 -> uint8
# V119, range: (0, 34), dtype: uint8 -> uint8
# V120, range: (0, 34), dtype: uint8 -> uint8
# V121, range: (0, 34), dtype: uint8 -> uint8
# V122, range: (0, 34), dtype: uint8 -> uint8
# V123, range: (0, 34), dtype: uint8 -> uint8
# V124, range: (0, 34), dtype: uint8 -> uint8
# V125, range: (0, 34), dtype: uint8 -> uint8
# V126, range: (-32222.0, 160000.0), dtype: float32 -> float32
# V127, range: (-32222.0, 160000.0), dtype: float32 -> float32
# V128, range: (-32222.0, 160000.0), dtype: float32 -> float32
# V129, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V130, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V131, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V132, range: (-32222.0, 93736.0), dtype: float32 -> float32
# V133, range: (-32222.0, 133915.0), dtype: float32 -> float32
# V134, range: (-32222.0, 98476.0), dtype: float32 -> float32
# V135, range: (-32222.0, 90750.0), dtype: float32 -> float32
# V136, range: (-32222.0, 90750.0), dtype: float32 -> float32
# V137, range: (-32222.0, 90750.0), dtype: float32 -> float32
# V138, range: (0, 34), dtype: uint8 -> uint8
# V139, range: (0, 34), dtype: uint8 -> uint8
# V140, range: (0, 34), dtype: uint8 -> uint8
# V141, range: (0, 34), dtype: uint8 -> uint8
# V142, range: (0, 34), dtype: uint8 -> uint8
# V143, range: (0, 33314), dtype: uint16 -> uint16
# V144, range: (0, 62), dtype: uint8 -> uint8
# V145, range: (0, 33314), dtype: uint16 -> uint16
# V146, range: (0, 34), dtype: uint8 -> uint8
# V147, range: (0, 34), dtype: uint8 -> uint8
# V148, range: (0, 34), dtype: uint8 -> uint8
# V149, range: (0, 34), dtype: uint8 -> uint8
# V150, range: (1, 33314), dtype: uint16 -> uint16
# V151, range: (1, 57), dtype: uint8 -> uint8
# V152, range: (1, 69), dtype: uint8 -> uint8
# V153, range: (0, 34), dtype: uint8 -> uint8
# V154, range: (0, 34), dtype: uint8 -> uint8
# V155, range: (0, 34), dtype: uint8 -> uint8
# V156, range: (0, 34), dtype: uint8 -> uint8
# V157, range: (0, 34), dtype: uint8 -> uint8
# V158, range: (0, 34), dtype: uint8 -> uint8
# V159, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V160, range: (-32222.0, 641511.4375), dtype: float32 -> float32
# V161, range: (-32222.0, 3300.0), dtype: float32 -> float32
# V162, range: (-32222.0, 3300.0), dtype: float32 -> float32
# V163, range: (-32222.0, 3300.0), dtype: float32 -> float32
# V164, range: (-32222.0, 93736.0), dtype: float32 -> float32
# V165, range: (-32222.0, 98476.0), dtype: float32 -> float32
# V166, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V167, range: (0, 33314), dtype: uint16 -> uint16
# V168, range: (0, 33314), dtype: uint16 -> uint16
# V169, range: (0, 34), dtype: uint8 -> uint8
# V170, range: (0, 48), dtype: uint8 -> uint8
# V171, range: (0, 61), dtype: uint8 -> uint8
# V172, range: (0, 34), dtype: uint8 -> uint8
# V173, range: (0, 34), dtype: uint8 -> uint8
# V174, range: (0, 34), dtype: uint8 -> uint8
# V175, range: (0, 34), dtype: uint8 -> uint8
# V176, range: (0, 48), dtype: uint8 -> uint8
# V177, range: (0, 33314), dtype: uint16 -> uint16
# V178, range: (0, 33314), dtype: uint16 -> uint16
# V179, range: (0, 33314), dtype: uint16 -> uint16
# V180, range: (0, 83), dtype: uint8 -> uint8
# V181, range: (0, 34), dtype: uint8 -> uint8
# V182, range: (0, 83), dtype: uint8 -> uint8
# V183, range: (0, 41), dtype: uint8 -> uint8
# V184, range: (0, 34), dtype: uint8 -> uint8
# V185, range: (0, 34), dtype: uint8 -> uint8
# V186, range: (0, 38), dtype: uint8 -> uint8
# V187, range: (0, 218), dtype: uint8 -> uint8
# V188, range: (0, 34), dtype: uint8 -> uint8
# V189, range: (0, 34), dtype: uint8 -> uint8
# V190, range: (0, 42), dtype: uint8 -> uint8
# V191, range: (0, 34), dtype: uint8 -> uint8
# V192, range: (0, 44), dtype: uint8 -> uint8
# V193, range: (0, 37), dtype: uint8 -> uint8
# V194, range: (0, 34), dtype: uint8 -> uint8
# V195, range: (0, 34), dtype: uint8 -> uint8
# V196, range: (0, 38), dtype: uint8 -> uint8
# V197, range: (0, 34), dtype: uint8 -> uint8
# V198, range: (0, 34), dtype: uint8 -> uint8
# V199, range: (0, 45), dtype: uint8 -> uint8
# V200, range: (0, 45), dtype: uint8 -> uint8
# V201, range: (0, 55), dtype: uint8 -> uint8
# V202, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V203, range: (-32222.0, 139777.0), dtype: float32 -> float32
# V204, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V205, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V206, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V207, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V208, range: (-32222.0, 3300.0), dtype: float32 -> float32
# V209, range: (-32222.0, 8050.0), dtype: float32 -> float32
# V210, range: (-32222.0, 3300.0), dtype: float32 -> float32
# V211, range: (-32222.0, 92888.0), dtype: float32 -> float32
# V212, range: (-32222.0, 129006.0), dtype: float32 -> float32
# V213, range: (-32222.0, 97628.0), dtype: float32 -> float32
# V214, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V215, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V216, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V217, range: (0, 33314), dtype: uint16 -> uint16
# V218, range: (0, 33314), dtype: uint16 -> uint16
# V219, range: (0, 33314), dtype: uint16 -> uint16
# V220, range: (0, 34), dtype: uint8 -> uint8
# V221, range: (0, 33314), dtype: uint16 -> uint16
# V222, range: (0, 33314), dtype: uint16 -> uint16
# V223, range: (0, 34), dtype: uint8 -> uint8
# V224, range: (0, 144), dtype: uint8 -> uint8
# V225, range: (0, 51), dtype: uint8 -> uint8
# V226, range: (0, 242), dtype: uint8 -> uint8
# V227, range: (0, 33314), dtype: uint16 -> uint16
# V228, range: (0, 54), dtype: uint8 -> uint8
# V229, range: (0, 176), dtype: uint8 -> uint8
# V230, range: (0, 65), dtype: uint8 -> uint8
# V231, range: (0, 33314), dtype: uint16 -> uint16
# V232, range: (0, 33314), dtype: uint16 -> uint16
# V233, range: (0, 33314), dtype: uint16 -> uint16
# V234, range: (0, 121), dtype: uint8 -> uint8
# V235, range: (0, 34), dtype: uint8 -> uint8
# V236, range: (0, 45), dtype: uint8 -> uint8
# V237, range: (0, 39), dtype: uint8 -> uint8
# V238, range: (0, 34), dtype: uint8 -> uint8
# V239, range: (0, 34), dtype: uint8 -> uint8
# V240, range: (0, 34), dtype: uint8 -> uint8
# V241, range: (0, 34), dtype: uint8 -> uint8
# V242, range: (0, 34), dtype: uint8 -> uint8
# V243, range: (0, 57), dtype: uint8 -> uint8
# V244, range: (0, 34), dtype: uint8 -> uint8
# V245, range: (0, 33314), dtype: uint16 -> uint16
# V246, range: (0, 45), dtype: uint8 -> uint8
# V247, range: (0, 34), dtype: uint8 -> uint8
# V248, range: (0, 36), dtype: uint8 -> uint8
# V249, range: (0, 34), dtype: uint8 -> uint8
# V250, range: (0, 34), dtype: uint8 -> uint8
# V251, range: (0, 34), dtype: uint8 -> uint8
# V252, range: (0, 34), dtype: uint8 -> uint8
# V253, range: (0, 163), dtype: uint8 -> uint8
# V254, range: (0, 60), dtype: uint8 -> uint8
# V255, range: (0, 87), dtype: uint8 -> uint8
# V256, range: (0, 87), dtype: uint8 -> uint8
# V257, range: (0, 48), dtype: uint8 -> uint8
# V258, range: (0, 66), dtype: uint8 -> uint8
# V259, range: (0, 33314), dtype: uint16 -> uint16
# V260, range: (0, 34), dtype: uint8 -> uint8
# V261, range: (0, 49), dtype: uint8 -> uint8
# V262, range: (0, 34), dtype: uint8 -> uint8
# V263, range: (-32222.0, 153600.0), dtype: float32 -> float32
# V264, range: (-32222.0, 153600.0), dtype: float32 -> float32
# V265, range: (-32222.0, 153600.0), dtype: float32 -> float32
# V266, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V267, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V268, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V269, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V270, range: (-32222.0, 4000.0), dtype: float32 -> float32
# V271, range: (-32222.0, 4000.0), dtype: float32 -> float32
# V272, range: (-32222.0, 4000.0), dtype: float32 -> float32
# V273, range: (-32222.0, 51200.0), dtype: float32 -> float32
# V274, range: (-32222.0, 66000.0), dtype: float32 -> float32
# V275, range: (-32222.0, 51200.0), dtype: float32 -> float32
# V276, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V277, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V278, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V279, range: (0, 33314), dtype: uint16 -> uint16
# V280, range: (0, 33314), dtype: uint16 -> uint16
# V281, range: (0, 34), dtype: uint8 -> uint8
# V282, range: (0, 34), dtype: uint8 -> uint8
# V283, range: (0, 68), dtype: uint8 -> uint8
# V284, range: (0, 34), dtype: uint8 -> uint8
# V285, range: (0, 95), dtype: uint8 -> uint8
# V286, range: (0, 34), dtype: uint8 -> uint8
# V287, range: (0, 34), dtype: uint8 -> uint8
# V288, range: (0, 34), dtype: uint8 -> uint8
# V289, range: (0, 34), dtype: uint8 -> uint8
# V290, range: (1, 67), dtype: uint8 -> uint8
# V291, range: (1, 33314), dtype: uint16 -> uint16
# V292, range: (1, 33314), dtype: uint16 -> uint16
# V293, range: (0, 33314), dtype: uint16 -> uint16
# V294, range: (0, 33314), dtype: uint16 -> uint16
# V295, range: (0, 33314), dtype: uint16 -> uint16
# V296, range: (0, 93), dtype: uint8 -> uint8
# V297, range: (0, 34), dtype: uint8 -> uint8
# V298, range: (0, 93), dtype: uint8 -> uint8
# V299, range: (0, 49), dtype: uint8 -> uint8
# V300, range: (0, 34), dtype: uint8 -> uint8
# V301, range: (0, 34), dtype: uint8 -> uint8
# V302, range: (0, 34), dtype: uint8 -> uint8
# V303, range: (0, 34), dtype: uint8 -> uint8
# V304, range: (0, 34), dtype: uint8 -> uint8
# V305, range: (1, 34), dtype: uint8 -> uint8
# V306, range: (-32222.0, 108800.0), dtype: float32 -> float32
# V307, range: (-32222.0, 145765.0), dtype: float32 -> float32
# V308, range: (-32222.0, 108800.0), dtype: float32 -> float32
# V309, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V310, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V311, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V312, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V313, range: (-32222.0, 4817.47021484375), dtype: float32 -> float32
# V314, range: (-32222.0, 7519.8701171875), dtype: float32 -> float32
# V315, range: (-32222.0, 4817.47021484375), dtype: float32 -> float32
# V316, range: (-32222.0, 93736.0), dtype: float32 -> float32
# V317, range: (-32222.0, 134021.0), dtype: float32 -> float32
# V318, range: (-32222.0, 98476.0), dtype: float32 -> float32
# V319, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V320, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V321, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V322, range: (0, 33314), dtype: uint16 -> uint16
# V323, range: (0, 33314), dtype: uint16 -> uint16
# V324, range: (0, 33314), dtype: uint16 -> uint16
# V325, range: (0, 34), dtype: uint8 -> uint8
# V326, range: (0, 44), dtype: uint8 -> uint8
# V327, range: (0, 34), dtype: uint8 -> uint8
# V328, range: (0, 34), dtype: uint8 -> uint8
# V329, range: (0, 99), dtype: uint8 -> uint8
# V330, range: (0, 55), dtype: uint8 -> uint8
# V331, range: (-32222.0, 160000.0), dtype: float32 -> float32
# V332, range: (-32222.0, 160000.0), dtype: float32 -> float32
# V333, range: (-32222.0, 160000.0), dtype: float32 -> float32
# V334, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V335, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V336, range: (-32222.0, 55125.0), dtype: float32 -> float32
# V337, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V338, range: (-32222.0, 104060.0), dtype: float32 -> float32
# V339, range: (-32222.0, 104060.0), dtype: float32 -> float32
# id_01, range: (-100, 34), dtype: int8 -> int8
# id_02, range: (1, 4294935074), dtype: uint32 -> uint32
# id_03, range: (-13, 34), dtype: int8 -> int8
# id_04, range: (-28, 34), dtype: int8 -> int8
# id_05, range: (-72, 52), dtype: int8 -> int8
# id_06, range: (-100, 34), dtype: int8 -> int8
# id_07, range: (-46, 61), dtype: int8 -> int8
# id_08, range: (-100, 34), dtype: int8 -> int8
# id_09, range: (-36, 34), dtype: int8 -> int8
# id_10, range: (-100, 34), dtype: int8 -> int8
# id_11, range: (-32222.0, 100.0), dtype: float32 -> float32
# id_12, range: (0.0, 1.0), dtype: float64 -> uint8
# id_13, range: (10, 64), dtype: uint8 -> uint8
# id_14, range: (-32222, 720), dtype: int16 -> int16
# id_15, range: (-1.0, 2.0), dtype: float64 -> int8
# id_16, range: (0.0, 1.0), dtype: float64 -> uint8
# id_17, range: (34, 229), dtype: uint8 -> uint8
# id_18, range: (10, 34), dtype: uint8 -> uint8
# id_19, range: (100, 33314), dtype: uint16 -> uint16
# id_20, range: (100, 33314), dtype: uint16 -> uint16
# id_21, range: (100, 33314), dtype: uint16 -> uint16
# id_22, range: (10, 44), dtype: uint8 -> uint8
# id_23, range: (1.0, 2.0), dtype: float64 -> uint8
# id_24, range: (11, 34), dtype: uint8 -> uint8
# id_25, range: (100, 33314), dtype: uint16 -> uint16
# id_26, range: (34, 216), dtype: uint8 -> uint8
# id_27, range: (0.0, 1.0), dtype: float64 -> uint8
# id_28, range: (1.0, 2.0), dtype: float64 -> uint8
# id_29, range: (0.0, 1.0), dtype: float64 -> uint8
# id_30, range: (0, 87), dtype: int64 -> uint8
# id_31, range: (0, 172), dtype: int64 -> uint8
# id_32, range: (0, 34), dtype: uint8 -> uint8
# id_33, range: (2, 460), dtype: int64 -> uint16
# id_34, range: (-1.0, 2.0), dtype: float64 -> int8
# id_35, range: (0.0, 1.0), dtype: float64 -> uint8
# id_36, range: (0.0, 1.0), dtype: float64 -> uint8
# id_37, range: (0.0, 1.0), dtype: float64 -> uint8
# id_38, range: (0.0, 1.0), dtype: float64 -> uint8
# DeviceType, range: (0.0, 1.0), dtype: float64 -> uint8
# DeviceInfo, range: (0, 2799), dtype: int64 -> uint16
# Cents, range: (0, 999), dtype: uint16 -> uint16
# Hour, range: (0, 23), dtype: uint8 -> uint8
# DayOfWeek, range: (0, 6), dtype: uint8 -> uint8
# DayOfMonth, range: (1, 31), dtype: uint8 -> uint8
# MonthFraction, range: (3, 100), dtype: uint8 -> uint8
# isDecember, range: (0, 1), dtype: uint8 -> uint8
# card1__addr1, range: (0, 55369), dtype: int64 -> uint16
# card1__addr1_count, range: (1, 21461), dtype: uint16 -> uint16
# card1__card5, range: (0, 18807), dtype: int64 -> uint16
# card1__card5_count, range: (1, 26121), dtype: uint16 -> uint16
# card2__dist1, range: (0, 31407), dtype: int64 -> uint16
# card2__id_20, range: (0, 9239), dtype: int64 -> uint16
# card5__P_emaildomain, range: (0, 1573), dtype: int64 -> uint16
# uuid3_count, range: (1, 21360), dtype: uint16 -> uint16
# TransactionAmt_mean_by_uuid2_ProductCD, range: (0.6150000095367432, 4545.35986328125), dtype: float32 -> float32
# dist2_mean_by_uuid2_addr1, range: (-32222.0, 11623.0), dtype: float32 -> float32
# V313_mean_by_V307, range: (-32222.0, 4817.47021484375), dtype: float32 -> float32
# TransactionAmt_mean_by_uuid3, range: (0.5879999995231628, 4545.35986328125), dtype: float32 -> float32
# TransactionAmt_std_by_uuid3, range: (-32222.0, 6547.81884765625), dtype: float32 -> float32
# TransactionAmt_mean_by_uuid2, range: (0.6150000095367432, 4545.35986328125), dtype: float32 -> float32
# TransactionAmt_mean_by_uuid, range: (0.6150000095367432, 4545.35986328125), dtype: float32 -> float32
# TransactionAmt_mean_by_card1, range: (0.6150000095367432, 3454.949951171875), dtype: float32 -> float32
# card1_count, range: (1, 28015), dtype: uint16 -> uint16
# card2_count, range: (123, 91731), dtype: uint32 -> uint32
# card5_count, range: (1, 553537), dtype: uint32 -> uint32
# addr1_count, range: (1, 131315), dtype: uint32 -> uint32
# addr2_count, range: (1, 956415), dtype: uint32 -> uint32
# dist1_count, range: (1, 643488), dtype: uint32 -> uint32
# C1_count, range: (1, 586742), dtype: uint32 -> uint32
# C2_count, range: (1, 581696), dtype: uint32 -> uint32
# C5_count, range: (2, 707008), dtype: uint32 -> uint32
# C6_count, range: (1, 631237), dtype: uint32 -> uint32
# C7_count, range: (1, 961237), dtype: uint32 -> uint32
# C9_count, range: (1, 420354), dtype: uint32 -> uint32
# C11_count, range: (1, 731792), dtype: uint32 -> uint32
# C13_count, range: (1, 367617), dtype: uint32 -> uint32
# C14_count, range: (1, 598520), dtype: uint32 -> uint32
# P_emaildomain_count, range: (80, 435803), dtype: uint32 -> uint32
# DeviceInfo_count, range: (1, 863508), dtype: uint32 -> uint32
# D2_na, range: (0, 1), dtype: uint8 -> uint8
# D3_na, range: (0, 1), dtype: uint8 -> uint8
# D5_na, range: (0, 1), dtype: uint8 -> uint8
# D6_na, range: (0, 1), dtype: uint8 -> uint8
# D7_na, range: (0, 1), dtype: uint8 -> uint8
# D13_na, range: (0, 1), dtype: uint8 -> uint8
# D14_na, range: (0, 1), dtype: uint8 -> uint8
# M4_na, range: (0, 1), dtype: uint8 -> uint8
# M5_na, range: (0, 1), dtype: uint8 -> uint8
# M6_na, range: (0, 1), dtype: uint8 -> uint8
# M7_na, range: (0, 1), dtype: uint8 -> uint8
# M8_na, range: (0, 1), dtype: uint8 -> uint8
# P_emaildomain_parts, range: (0, 3), dtype: uint8 -> uint8
# P_emaildomain_sfx2, range: (0, 9), dtype: int64 -> uint8
# P_emaildomain_sfx1, range: (0, 10), dtype: int64 -> uint8
# P_emaildomain_bin, range: (0, 9), dtype: int64 -> uint8
# R_emaildomain_parts, range: (0, 3), dtype: uint8 -> uint8
# R_emaildomain_sfx2, range: (0, 9), dtype: int64 -> uint8
# R_emaildomain_sfx1, range: (0, 10), dtype: int64 -> uint8
# R_emaildomain_bin, range: (0, 9), dtype: int64 -> uint8
# Browser, range: (-1, 6), dtype: int8 -> int8
# OS, range: (-1, 4), dtype: int8 -> int8
# id_16_na, range: (False, True), dtype: bool -> uint8
# id_33_0, range: (0, 7500), dtype: int64 -> uint16
# id_33_1, range: (0, 5000), dtype: int64 -> uint16
#
#  *** DONE ***
# Memory usage: 700.89 -> 539.25 MB
# This is 76.94% of the initial size

# %%
df_test, na_test = reduce_mem_usage(df_test)
for df, filename in zip([df_test, na_test], ['df_test.pkl', 'na_test.pkl']):
    save_to_disk(df, filename)
# Out:
# TransactionAmt, range: (0.017999999225139618, 10270.0), dtype: float32 -> float32
# ProductCD, range: (23046, 800657), dtype: int64 -> uint32
# card1, range: (1001, 18397), dtype: uint16 -> uint16
# card2, range: (100, 33314), dtype: uint16 -> uint16
# card3, range: (34, 232), dtype: uint8 -> uint8
# card4, range: (9524.0, 719649.0), dtype: float64 -> uint32
# card5, range: (34, 237), dtype: uint8 -> uint8
# card6, range: (16.0, 824959.0), dtype: float64 -> uint32
# addr1, range: (100, 33314), dtype: uint16 -> uint16
# addr2, range: (10, 102), dtype: uint8 -> uint8
# dist1, range: (0, 33314), dtype: uint16 -> uint16
# dist2, range: (0, 33314), dtype: uint16 -> uint16
# P_emaildomain, range: (0, 60), dtype: int64 -> uint8
# R_emaildomain, range: (0, 60), dtype: int64 -> uint8
# C1, range: (0, 33314), dtype: uint16 -> uint16
# C2, range: (0, 33314), dtype: uint16 -> uint16
# C3, range: (0, 34), dtype: uint8 -> uint8
# C4, range: (0, 33314), dtype: uint16 -> uint16
# C5, range: (0, 33314), dtype: uint16 -> uint16
# C6, range: (0, 33314), dtype: uint16 -> uint16
# C7, range: (0, 33314), dtype: uint16 -> uint16
# C8, range: (0, 33314), dtype: uint16 -> uint16
# C9, range: (0, 33314), dtype: uint16 -> uint16
# C10, range: (0, 33314), dtype: uint16 -> uint16
# C11, range: (0, 33314), dtype: uint16 -> uint16
# C12, range: (0, 33314), dtype: uint16 -> uint16
# C13, range: (0, 33314), dtype: uint16 -> uint16
# C14, range: (0, 33314), dtype: uint16 -> uint16
# D1, range: (0, 33314), dtype: uint16 -> uint16
# D2, range: (0, 33314), dtype: uint16 -> uint16
# D3, range: (0, 33314), dtype: uint16 -> uint16
# D4, range: (0, 33314), dtype: uint16 -> uint16
# D5, range: (0, 33314), dtype: uint16 -> uint16
# D6, range: (0, 33314), dtype: uint16 -> uint16
# D7, range: (0, 33314), dtype: uint16 -> uint16
# D8, range: (-32222.0, 2029.5833740234375), dtype: float32 -> float32
# D9, range: (-32222.0, 0.9583330154418945), dtype: float32 -> float32
# D10, range: (0, 33314), dtype: uint16 -> uint16
# D11, range: (0, 33314), dtype: uint16 -> uint16
# D12, range: (0, 33314), dtype: uint16 -> uint16
# D13, range: (0, 33314), dtype: uint16 -> uint16
# D14, range: (0, 33314), dtype: uint16 -> uint16
# D15, range: (0, 33314), dtype: uint16 -> uint16
# M1, range: (0.0, 1.0), dtype: float64 -> uint8
# M2, range: (0.0, 1.0), dtype: float64 -> uint8
# M3, range: (0.0, 1.0), dtype: float64 -> uint8
# M4, range: (97306.0, 357789.0), dtype: float64 -> uint32
# M5, range: (0.0, 1.0), dtype: float64 -> uint8
# M6, range: (0.0, 1.0), dtype: float64 -> uint8
# M7, range: (0.0, 1.0), dtype: float64 -> uint8
# M8, range: (0.0, 1.0), dtype: float64 -> uint8
# M9, range: (0.0, 1.0), dtype: float64 -> uint8
# V1, range: (0, 34), dtype: uint8 -> uint8
# V2, range: (0, 34), dtype: uint8 -> uint8
# V3, range: (0, 34), dtype: uint8 -> uint8
# V4, range: (0, 34), dtype: uint8 -> uint8
# V5, range: (0, 34), dtype: uint8 -> uint8
# V6, range: (0, 34), dtype: uint8 -> uint8
# V7, range: (0, 34), dtype: uint8 -> uint8
# V8, range: (0, 34), dtype: uint8 -> uint8
# V9, range: (0, 34), dtype: uint8 -> uint8
# V10, range: (0, 34), dtype: uint8 -> uint8
# V11, range: (0, 34), dtype: uint8 -> uint8
# V12, range: (0, 34), dtype: uint8 -> uint8
# V13, range: (0, 34), dtype: uint8 -> uint8
# V14, range: (0, 34), dtype: uint8 -> uint8
# V15, range: (0, 34), dtype: uint8 -> uint8
# V16, range: (0, 34), dtype: uint8 -> uint8
# V17, range: (0, 34), dtype: uint8 -> uint8
# V18, range: (0, 34), dtype: uint8 -> uint8
# V19, range: (0, 34), dtype: uint8 -> uint8
# V20, range: (0, 34), dtype: uint8 -> uint8
# V21, range: (0, 34), dtype: uint8 -> uint8
# V22, range: (0, 34), dtype: uint8 -> uint8
# V23, range: (0, 34), dtype: uint8 -> uint8
# V24, range: (0, 34), dtype: uint8 -> uint8
# V25, range: (0, 34), dtype: uint8 -> uint8
# V26, range: (0, 34), dtype: uint8 -> uint8
# V27, range: (0, 34), dtype: uint8 -> uint8
# V28, range: (0, 34), dtype: uint8 -> uint8
# V29, range: (0, 34), dtype: uint8 -> uint8
# V30, range: (0, 34), dtype: uint8 -> uint8
# V31, range: (0, 34), dtype: uint8 -> uint8
# V32, range: (0, 34), dtype: uint8 -> uint8
# V33, range: (0, 34), dtype: uint8 -> uint8
# V34, range: (0, 34), dtype: uint8 -> uint8
# V35, range: (0, 34), dtype: uint8 -> uint8
# V36, range: (0, 34), dtype: uint8 -> uint8
# V37, range: (0, 49), dtype: uint8 -> uint8
# V38, range: (0, 52), dtype: uint8 -> uint8
# V39, range: (0, 34), dtype: uint8 -> uint8
# V40, range: (0, 34), dtype: uint8 -> uint8
# V41, range: (0, 34), dtype: uint8 -> uint8
# V42, range: (0, 34), dtype: uint8 -> uint8
# V43, range: (0, 34), dtype: uint8 -> uint8
# V44, range: (0, 47), dtype: uint8 -> uint8
# V45, range: (0, 69), dtype: uint8 -> uint8
# V46, range: (0, 34), dtype: uint8 -> uint8
# V47, range: (0, 34), dtype: uint8 -> uint8
# V48, range: (0, 34), dtype: uint8 -> uint8
# V49, range: (0, 34), dtype: uint8 -> uint8
# V50, range: (0, 34), dtype: uint8 -> uint8
# V51, range: (0, 34), dtype: uint8 -> uint8
# V52, range: (0, 34), dtype: uint8 -> uint8
# V53, range: (0, 34), dtype: uint8 -> uint8
# V54, range: (0, 34), dtype: uint8 -> uint8
# V55, range: (0, 49), dtype: uint8 -> uint8
# V56, range: (0, 51), dtype: uint8 -> uint8
# V57, range: (0, 34), dtype: uint8 -> uint8
# V58, range: (0, 34), dtype: uint8 -> uint8
# V59, range: (0, 34), dtype: uint8 -> uint8
# V60, range: (0, 34), dtype: uint8 -> uint8
# V61, range: (0, 34), dtype: uint8 -> uint8
# V62, range: (0, 34), dtype: uint8 -> uint8
# V63, range: (0, 34), dtype: uint8 -> uint8
# V64, range: (0, 34), dtype: uint8 -> uint8
# V65, range: (0, 34), dtype: uint8 -> uint8
# V66, range: (0, 34), dtype: uint8 -> uint8
# V67, range: (0, 34), dtype: uint8 -> uint8
# V68, range: (0, 34), dtype: uint8 -> uint8
# V69, range: (0, 34), dtype: uint8 -> uint8
# V70, range: (0, 34), dtype: uint8 -> uint8
# V71, range: (0, 34), dtype: uint8 -> uint8
# V72, range: (0, 34), dtype: uint8 -> uint8
# V73, range: (0, 34), dtype: uint8 -> uint8
# V74, range: (0, 34), dtype: uint8 -> uint8
# V75, range: (0, 34), dtype: uint8 -> uint8
# V76, range: (0, 34), dtype: uint8 -> uint8
# V77, range: (0, 80), dtype: uint8 -> uint8
# V78, range: (0, 80), dtype: uint8 -> uint8
# V79, range: (0, 34), dtype: uint8 -> uint8
# V80, range: (0, 34), dtype: uint8 -> uint8
# V81, range: (0, 34), dtype: uint8 -> uint8
# V82, range: (0, 34), dtype: uint8 -> uint8
# V83, range: (0, 34), dtype: uint8 -> uint8
# V84, range: (0, 34), dtype: uint8 -> uint8
# V85, range: (0, 34), dtype: uint8 -> uint8
# V86, range: (0, 80), dtype: uint8 -> uint8
# V87, range: (0, 80), dtype: uint8 -> uint8
# V88, range: (0, 34), dtype: uint8 -> uint8
# V89, range: (0, 34), dtype: uint8 -> uint8
# V90, range: (0, 34), dtype: uint8 -> uint8
# V91, range: (0, 34), dtype: uint8 -> uint8
# V92, range: (0, 34), dtype: uint8 -> uint8
# V93, range: (0, 34), dtype: uint8 -> uint8
# V94, range: (0, 34), dtype: uint8 -> uint8
# V95, range: (0, 60), dtype: uint8 -> uint8
# V96, range: (0, 103), dtype: uint8 -> uint8
# V97, range: (0, 82), dtype: uint8 -> uint8
# V98, range: (0, 8), dtype: uint8 -> uint8
# V99, range: (0, 62), dtype: uint8 -> uint8
# V100, range: (0, 30), dtype: uint8 -> uint8
# V101, range: (0, 18), dtype: uint8 -> uint8
# V102, range: (0, 68), dtype: uint8 -> uint8
# V103, range: (0, 29), dtype: uint8 -> uint8
# V104, range: (0, 59), dtype: uint8 -> uint8
# V105, range: (0, 99), dtype: uint8 -> uint8
# V106, range: (0, 80), dtype: uint8 -> uint8
# V107, range: (1, 1), dtype: uint8 -> uint8
# V108, range: (0, 8), dtype: uint8 -> uint8
# V109, range: (0, 8), dtype: uint8 -> uint8
# V110, range: (0, 8), dtype: uint8 -> uint8
# V111, range: (0, 8), dtype: uint8 -> uint8
# V112, range: (0, 8), dtype: uint8 -> uint8
# V113, range: (0, 8), dtype: uint8 -> uint8
# V114, range: (0, 9), dtype: uint8 -> uint8
# V115, range: (0, 9), dtype: uint8 -> uint8
# V116, range: (0, 9), dtype: uint8 -> uint8
# V117, range: (0, 2), dtype: uint8 -> uint8
# V118, range: (0, 3), dtype: uint8 -> uint8
# V119, range: (0, 2), dtype: uint8 -> uint8
# V120, range: (0, 4), dtype: uint8 -> uint8
# V121, range: (0, 4), dtype: uint8 -> uint8
# V122, range: (0, 4), dtype: uint8 -> uint8
# V123, range: (0, 12), dtype: uint8 -> uint8
# V124, range: (0, 13), dtype: uint8 -> uint8
# V125, range: (0, 12), dtype: uint8 -> uint8
# V126, range: (0.0, 519038.5), dtype: float32 -> float32
# V127, range: (0.0, 544500.0), dtype: float32 -> float32
# V128, range: (0.0, 519038.5), dtype: float32 -> float32
# V129, range: (0.0, 64800.0), dtype: float32 -> float32
# V130, range: (0.0, 167200.0), dtype: float32 -> float32
# V131, range: (0.0, 167200.0), dtype: float32 -> float32
# V132, range: (0.0, 519038.5), dtype: float32 -> float32
# V133, range: (0.0, 519038.5), dtype: float32 -> float32
# V134, range: (0.0, 519038.5), dtype: float32 -> float32
# V135, range: (0.0, 302500.0), dtype: float32 -> float32
# V136, range: (0.0, 302500.0), dtype: float32 -> float32
# V137, range: (0.0, 302500.0), dtype: float32 -> float32
# V138, range: (0, 34), dtype: uint8 -> uint8
# V139, range: (0, 34), dtype: uint8 -> uint8
# V140, range: (0, 59), dtype: uint8 -> uint8
# V141, range: (0, 34), dtype: uint8 -> uint8
# V142, range: (0, 34), dtype: uint8 -> uint8
# V143, range: (0, 56), dtype: uint8 -> uint8
# V144, range: (0, 85), dtype: uint8 -> uint8
# V145, range: (0, 33314), dtype: uint16 -> uint16
# V146, range: (0, 34), dtype: uint8 -> uint8
# V147, range: (0, 34), dtype: uint8 -> uint8
# V148, range: (0, 34), dtype: uint8 -> uint8
# V149, range: (0, 34), dtype: uint8 -> uint8
# V150, range: (1, 33314), dtype: uint16 -> uint16
# V151, range: (1, 58), dtype: uint8 -> uint8
# V152, range: (1, 67), dtype: uint8 -> uint8
# V153, range: (0, 34), dtype: uint8 -> uint8
# V154, range: (0, 34), dtype: uint8 -> uint8
# V155, range: (0, 34), dtype: uint8 -> uint8
# V156, range: (0, 34), dtype: uint8 -> uint8
# V157, range: (0, 34), dtype: uint8 -> uint8
# V158, range: (0, 34), dtype: uint8 -> uint8
# V159, range: (-32222.0, 284129.8125), dtype: float32 -> float32
# V160, range: (-32222.0, 3867868.5), dtype: float32 -> float32
# V161, range: (-32222.0, 2000.0), dtype: float32 -> float32
# V162, range: (-32222.0, 4000.0), dtype: float32 -> float32
# V163, range: (-32222.0, 4000.0), dtype: float32 -> float32
# V164, range: (-32222.0, 928882.0), dtype: float32 -> float32
# V165, range: (-32222.0, 928882.0), dtype: float32 -> float32
# V166, range: (-32222.0, 453750.0), dtype: float32 -> float32
# V167, range: (0, 238), dtype: uint8 -> uint8
# V168, range: (0, 33314), dtype: uint16 -> uint16
# V169, range: (0, 39), dtype: uint8 -> uint8
# V170, range: (0, 63), dtype: uint8 -> uint8
# V171, range: (0, 68), dtype: uint8 -> uint8
# V172, range: (0, 37), dtype: uint8 -> uint8
# V173, range: (0, 34), dtype: uint8 -> uint8
# V174, range: (0, 34), dtype: uint8 -> uint8
# V175, range: (0, 34), dtype: uint8 -> uint8
# V176, range: (1, 239), dtype: uint8 -> uint8
# V177, range: (0, 238), dtype: uint8 -> uint8
# V178, range: (0, 33314), dtype: uint16 -> uint16
# V179, range: (0, 33314), dtype: uint16 -> uint16
# V180, range: (0, 179), dtype: uint8 -> uint8
# V181, range: (0, 85), dtype: uint8 -> uint8
# V182, range: (0, 125), dtype: uint8 -> uint8
# V183, range: (0, 106), dtype: uint8 -> uint8
# V184, range: (0, 34), dtype: uint8 -> uint8
# V185, range: (0, 34), dtype: uint8 -> uint8
# V186, range: (0, 39), dtype: uint8 -> uint8
# V187, range: (0, 158), dtype: uint8 -> uint8
# V188, range: (0, 44), dtype: uint8 -> uint8
# V189, range: (0, 44), dtype: uint8 -> uint8
# V190, range: (0, 224), dtype: uint8 -> uint8
# V191, range: (0, 34), dtype: uint8 -> uint8
# V192, range: (0, 37), dtype: uint8 -> uint8
# V193, range: (0, 34), dtype: uint8 -> uint8
# V194, range: (0, 34), dtype: uint8 -> uint8
# V195, range: (0, 34), dtype: uint8 -> uint8
# V196, range: (0, 41), dtype: uint8 -> uint8
# V197, range: (0, 34), dtype: uint8 -> uint8
# V198, range: (0, 34), dtype: uint8 -> uint8
# V199, range: (0, 224), dtype: uint8 -> uint8
# V200, range: (0, 47), dtype: uint8 -> uint8
# V201, range: (0, 47), dtype: uint8 -> uint8
# V202, range: (-32222.0, 1065496.5), dtype: float32 -> float32
# V203, range: (-32222.0, 1065496.5), dtype: float32 -> float32
# V204, range: (-32222.0, 1065496.5), dtype: float32 -> float32
# V205, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V206, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V207, range: (-32222.0, 167200.0), dtype: float32 -> float32
# V208, range: (-32222.0, 4000.0), dtype: float32 -> float32
# V209, range: (-32222.0, 10000.0), dtype: float32 -> float32
# V210, range: (-32222.0, 4000.0), dtype: float32 -> float32
# V211, range: (-32222.0, 928882.0), dtype: float32 -> float32
# V212, range: (-32222.0, 958320.0), dtype: float32 -> float32
# V213, range: (-32222.0, 928882.0), dtype: float32 -> float32
# V214, range: (-32222.0, 453750.0), dtype: float32 -> float32
# V215, range: (-32222.0, 756250.0), dtype: float32 -> float32
# V216, range: (-32222.0, 756250.0), dtype: float32 -> float32
# V217, range: (0, 238), dtype: uint8 -> uint8
# V218, range: (0, 33314), dtype: uint16 -> uint16
# V219, range: (0, 33314), dtype: uint16 -> uint16
# V220, range: (0, 47), dtype: uint8 -> uint8
# V221, range: (0, 140), dtype: uint8 -> uint8
# V222, range: (0, 33314), dtype: uint16 -> uint16
# V223, range: (0, 34), dtype: uint8 -> uint8
# V224, range: (0, 91), dtype: uint8 -> uint8
# V225, range: (0, 58), dtype: uint8 -> uint8
# V226, range: (0, 33314), dtype: uint16 -> uint16
# V227, range: (0, 131), dtype: uint8 -> uint8
# V228, range: (1, 239), dtype: uint8 -> uint8
# V229, range: (1, 33314), dtype: uint16 -> uint16
# V230, range: (1, 33314), dtype: uint16 -> uint16
# V231, range: (0, 238), dtype: uint8 -> uint8
# V232, range: (0, 33314), dtype: uint16 -> uint16
# V233, range: (0, 33314), dtype: uint16 -> uint16
# V234, range: (0, 33314), dtype: uint16 -> uint16
# V235, range: (0, 34), dtype: uint8 -> uint8
# V236, range: (0, 57), dtype: uint8 -> uint8
# V237, range: (0, 34), dtype: uint8 -> uint8
# V238, range: (0, 34), dtype: uint8 -> uint8
# V239, range: (0, 34), dtype: uint8 -> uint8
# V240, range: (1, 34), dtype: uint8 -> uint8
# V241, range: (1, 34), dtype: uint8 -> uint8
# V242, range: (0, 34), dtype: uint8 -> uint8
# V243, range: (0, 54), dtype: uint8 -> uint8
# V244, range: (0, 34), dtype: uint8 -> uint8
# V245, range: (0, 124), dtype: uint8 -> uint8
# V246, range: (0, 224), dtype: uint8 -> uint8
# V247, range: (0, 34), dtype: uint8 -> uint8
# V248, range: (0, 34), dtype: uint8 -> uint8
# V249, range: (0, 34), dtype: uint8 -> uint8
# V250, range: (0, 34), dtype: uint8 -> uint8
# V251, range: (0, 34), dtype: uint8 -> uint8
# V252, range: (0, 34), dtype: uint8 -> uint8
# V253, range: (0, 96), dtype: uint8 -> uint8
# V254, range: (0, 39), dtype: uint8 -> uint8
# V255, range: (0, 53), dtype: uint8 -> uint8
# V256, range: (0, 53), dtype: uint8 -> uint8
# V257, range: (0, 224), dtype: uint8 -> uint8
# V258, range: (0, 33314), dtype: uint16 -> uint16
# V259, range: (0, 131), dtype: uint8 -> uint8
# V260, range: (0, 34), dtype: uint8 -> uint8
# V261, range: (0, 89), dtype: uint8 -> uint8
# V262, range: (0, 34), dtype: uint8 -> uint8
# V263, range: (-32222.0, 1065496.5), dtype: float32 -> float32
# V264, range: (-32222.0, 1065496.5), dtype: float32 -> float32
# V265, range: (-32222.0, 1065496.5), dtype: float32 -> float32
# V266, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V267, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V268, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V269, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V270, range: (-32222.0, 10791.5703125), dtype: float32 -> float32
# V271, range: (-32222.0, 10791.5703125), dtype: float32 -> float32
# V272, range: (-32222.0, 10791.5703125), dtype: float32 -> float32
# V273, range: (-32222.0, 928882.0), dtype: float32 -> float32
# V274, range: (-32222.0, 928882.0), dtype: float32 -> float32
# V275, range: (-32222.0, 928882.0), dtype: float32 -> float32
# V276, range: (-32222.0, 453750.0), dtype: float32 -> float32
# V277, range: (-32222.0, 756250.0), dtype: float32 -> float32
# V278, range: (-32222.0, 756250.0), dtype: float32 -> float32
# V279, range: (0, 86), dtype: uint8 -> uint8
# V280, range: (0, 108), dtype: uint8 -> uint8
# V281, range: (0, 34), dtype: uint8 -> uint8
# V282, range: (0, 63), dtype: uint8 -> uint8
# V283, range: (0, 68), dtype: uint8 -> uint8
# V284, range: (0, 34), dtype: uint8 -> uint8
# V285, range: (0, 90), dtype: uint8 -> uint8
# V286, range: (0, 34), dtype: uint8 -> uint8
# V287, range: (0, 34), dtype: uint8 -> uint8
# V288, range: (0, 34), dtype: uint8 -> uint8
# V289, range: (0, 34), dtype: uint8 -> uint8
# V290, range: (1, 49), dtype: uint8 -> uint8
# V291, range: (1, 250), dtype: uint8 -> uint8
# V292, range: (1, 75), dtype: uint8 -> uint8
# V293, range: (0, 62), dtype: uint8 -> uint8
# V294, range: (0, 246), dtype: uint8 -> uint8
# V295, range: (0, 78), dtype: uint8 -> uint8
# V296, range: (0, 179), dtype: uint8 -> uint8
# V297, range: (0, 85), dtype: uint8 -> uint8
# V298, range: (0, 125), dtype: uint8 -> uint8
# V299, range: (0, 106), dtype: uint8 -> uint8
# V300, range: (0, 34), dtype: uint8 -> uint8
# V301, range: (0, 34), dtype: uint8 -> uint8
# V302, range: (0, 34), dtype: uint8 -> uint8
# V303, range: (0, 34), dtype: uint8 -> uint8
# V304, range: (0, 34), dtype: uint8 -> uint8
# V305, range: (1, 34), dtype: uint8 -> uint8
# V306, range: (-32222.0, 718740.0), dtype: float32 -> float32
# V307, range: (-32222.0, 958320.0), dtype: float32 -> float32
# V308, range: (-32222.0, 718740.0), dtype: float32 -> float32
# V309, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V310, range: (-32222.0, 167200.0), dtype: float32 -> float32
# V311, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V312, range: (-32222.0, 167200.0), dtype: float32 -> float32
# V313, range: (-32222.0, 4727.9599609375), dtype: float32 -> float32
# V314, range: (-32222.0, 7539.75), dtype: float32 -> float32
# V315, range: (-32222.0, 4727.9599609375), dtype: float32 -> float32
# V316, range: (-32222.0, 718740.0), dtype: float32 -> float32
# V317, range: (-32222.0, 958320.0), dtype: float32 -> float32
# V318, range: (-32222.0, 718740.0), dtype: float32 -> float32
# V319, range: (-32222.0, 453750.0), dtype: float32 -> float32
# V320, range: (-32222.0, 605000.0), dtype: float32 -> float32
# V321, range: (-32222.0, 605000.0), dtype: float32 -> float32
# V322, range: (0, 86), dtype: uint8 -> uint8
# V323, range: (0, 128), dtype: uint8 -> uint8
# V324, range: (0, 108), dtype: uint8 -> uint8
# V325, range: (0, 34), dtype: uint8 -> uint8
# V326, range: (0, 44), dtype: uint8 -> uint8
# V327, range: (0, 34), dtype: uint8 -> uint8
# V328, range: (0, 85), dtype: uint8 -> uint8
# V329, range: (0, 125), dtype: uint8 -> uint8
# V330, range: (0, 106), dtype: uint8 -> uint8
# V331, range: (-32222.0, 1040657.5), dtype: float32 -> float32
# V332, range: (-32222.0, 1040657.5), dtype: float32 -> float32
# V333, range: (-32222.0, 1040657.5), dtype: float32 -> float32
# V334, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V335, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V336, range: (-32222.0, 64800.0), dtype: float32 -> float32
# V337, range: (-32222.0, 375000.0), dtype: float32 -> float32
# V338, range: (-32222.0, 612500.0), dtype: float32 -> float32
# V339, range: (-32222.0, 612500.0), dtype: float32 -> float32
# id_01, range: (-100, 34), dtype: int8 -> int8
# id_02, range: (2, 4294935074), dtype: uint32 -> uint32
# id_03, range: (-12, 34), dtype: int8 -> int8
# id_04, range: (-19, 34), dtype: int8 -> int8
# id_05, range: (-81, 52), dtype: int8 -> int8
# id_06, range: (-100, 34), dtype: int8 -> int8
# id_07, range: (-41, 59), dtype: int8 -> int8
# id_08, range: (-100, 34), dtype: int8 -> int8
# id_09, range: (-32, 34), dtype: int8 -> int8
# id_10, range: (-100, 34), dtype: int8 -> int8
# id_11, range: (-32222.0, 100.0), dtype: float32 -> float32
# id_12, range: (0.0, 1.0), dtype: float64 -> uint8
# id_13, range: (11, 63), dtype: uint8 -> uint8
# id_14, range: (-32222, 720), dtype: int16 -> int16
# id_15, range: (-1.0, 2.0), dtype: float64 -> int8
# id_16, range: (0.0, 1.0), dtype: float64 -> uint8
# id_17, range: (34, 228), dtype: uint8 -> uint8
# id_18, range: (11, 34), dtype: uint8 -> uint8
# id_19, range: (100, 33314), dtype: uint16 -> uint16
# id_20, range: (100, 33314), dtype: uint16 -> uint16
# id_21, range: (100, 33314), dtype: uint16 -> uint16
# id_22, range: (11, 44), dtype: uint8 -> uint8
# id_23, range: (1.0, 2.0), dtype: float64 -> uint8
# id_24, range: (10, 34), dtype: uint8 -> uint8
# id_25, range: (100, 33314), dtype: uint16 -> uint16
# id_26, range: (34, 216), dtype: uint8 -> uint8
# id_27, range: (0.0, 1.0), dtype: float64 -> uint8
# id_28, range: (1.0, 2.0), dtype: float64 -> uint8
# id_29, range: (0.0, 1.0), dtype: float64 -> uint8
# id_30, range: (0, 87), dtype: int64 -> uint8
# id_31, range: (16, 171), dtype: int64 -> uint8
# id_32, range: (8, 48), dtype: uint8 -> uint8
# id_33, range: (0, 460), dtype: int64 -> uint16
# id_34, range: (1.0, 2.0), dtype: float64 -> uint8
# id_35, range: (0.0, 1.0), dtype: float64 -> uint8
# id_36, range: (0.0, 1.0), dtype: float64 -> uint8
# id_37, range: (0.0, 1.0), dtype: float64 -> uint8
# id_38, range: (0.0, 1.0), dtype: float64 -> uint8
# DeviceType, range: (0.0, 1.0), dtype: float64 -> uint8
# DeviceInfo, range: (4, 2798), dtype: int64 -> uint16
# Cents, range: (0, 999), dtype: uint16 -> uint16
# Hour, range: (0, 23), dtype: uint8 -> uint8
# DayOfWeek, range: (0, 6), dtype: uint8 -> uint8
# DayOfMonth, range: (1, 31), dtype: uint8 -> uint8
# MonthFraction, range: (3, 100), dtype: uint8 -> uint8
# isDecember, range: (0, 1), dtype: uint8 -> uint8
# card1__addr1, range: (2, 55368), dtype: int64 -> uint16
# card1__addr1_count, range: (1, 21461), dtype: uint16 -> uint16
# card1__card5, range: (2, 18807), dtype: int64 -> uint16
# card1__card5_count, range: (1, 26121), dtype: uint16 -> uint16
# card2__dist1, range: (0, 31407), dtype: int64 -> uint16
# card2__id_20, range: (0, 9239), dtype: int64 -> uint16
# card5__P_emaildomain, range: (0, 1573), dtype: int64 -> uint16
# uuid3_count, range: (1, 21360), dtype: uint16 -> uint16
# TransactionAmt_mean_by_uuid2_ProductCD, range: (1.4670000076293945, 6237.4501953125), dtype: float32 -> float32
# dist2_mean_by_uuid2_addr1, range: (-32222.0, 8145.0), dtype: float32 -> float32
# V313_mean_by_V307, range: (-32222.0, 4727.9599609375), dtype: float32 -> float32
# TransactionAmt_mean_by_uuid3, range: (1.4670000076293945, 6237.4501953125), dtype: float32 -> float32
# TransactionAmt_std_by_uuid3, range: (-32222.0, 3334.715576171875), dtype: float32 -> float32
# TransactionAmt_mean_by_uuid2, range: (2.6459999084472656, 4327.02001953125), dtype: float32 -> float32
# TransactionAmt_mean_by_uuid, range: (2.6459999084472656, 4327.02001953125), dtype: float32 -> float32
# TransactionAmt_mean_by_card1, range: (2.6459999084472656, 4327.02001953125), dtype: float32 -> float32
# card1_count, range: (1, 28015), dtype: uint16 -> uint16
# card2_count, range: (123, 91731), dtype: uint32 -> uint32
# card5_count, range: (1, 553537), dtype: uint32 -> uint32
# addr1_count, range: (1, 131315), dtype: uint32 -> uint32
# addr2_count, range: (1, 956415), dtype: uint32 -> uint32
# dist1_count, range: (1, 643488), dtype: uint32 -> uint32
# C1_count, range: (1, 586742), dtype: uint32 -> uint32
# C2_count, range: (1, 581696), dtype: uint32 -> uint32
# C5_count, range: (1, 707008), dtype: uint32 -> uint32
# C6_count, range: (1, 631237), dtype: uint32 -> uint32
# C7_count, range: (1, 961237), dtype: uint32 -> uint32
# C9_count, range: (1, 420354), dtype: uint32 -> uint32
# C11_count, range: (1, 731792), dtype: uint32 -> uint32
# C13_count, range: (1, 367617), dtype: uint32 -> uint32
# C14_count, range: (1, 598520), dtype: uint32 -> uint32
# P_emaildomain_count, range: (2, 435803), dtype: uint32 -> uint32
# DeviceInfo_count, range: (1, 863508), dtype: uint32 -> uint32
# D2_na, range: (0, 1), dtype: uint8 -> uint8
# D3_na, range: (0, 1), dtype: uint8 -> uint8
# D5_na, range: (0, 1), dtype: uint8 -> uint8
# D6_na, range: (0, 1), dtype: uint8 -> uint8
# D7_na, range: (0, 1), dtype: uint8 -> uint8
# D13_na, range: (0, 1), dtype: uint8 -> uint8
# D14_na, range: (0, 1), dtype: uint8 -> uint8
# M4_na, range: (0, 1), dtype: uint8 -> uint8
# M5_na, range: (0, 1), dtype: uint8 -> uint8
# M6_na, range: (0, 1), dtype: uint8 -> uint8
# M7_na, range: (0, 1), dtype: uint8 -> uint8
# M8_na, range: (0, 1), dtype: uint8 -> uint8
# P_emaildomain_parts, range: (0, 3), dtype: uint8 -> uint8
# P_emaildomain_sfx2, range: (0, 9), dtype: int64 -> uint8
# P_emaildomain_sfx1, range: (0, 10), dtype: int64 -> uint8
# P_emaildomain_bin, range: (0, 9), dtype: int64 -> uint8
# R_emaildomain_parts, range: (0, 3), dtype: uint8 -> uint8
# R_emaildomain_sfx2, range: (0, 9), dtype: int64 -> uint8
# R_emaildomain_sfx1, range: (0, 10), dtype: int64 -> uint8
# R_emaildomain_bin, range: (0, 9), dtype: int64 -> uint8
# Browser, range: (-1, 6), dtype: int8 -> int8
# OS, range: (-1, 4), dtype: int8 -> int8
# id_16_na, range: (False, True), dtype: bool -> uint8
# id_33_0, range: (0, 8960), dtype: int64 -> uint16
# id_33_1, range: (0, 5040), dtype: int64 -> uint16
#
#  *** DONE ***
# Memory usage: 595.03 -> 456.35 MB
# This is 76.69% of the initial size

# %% [markdown]
# # Modelling

# %%
params = {
    'num_leaves': 512,
    'min_child_weight': 0.035,
    'feature_fraction': 0.25,
    'bagging_fraction': 0.22,
    'min_data_in_leaf': 100,
    'objective': 'binary',
    'max_depth': -1,
    'learning_rate': 0.006,
    "boosting_type": "gbdt",
    "bagging_seed": 57,
    "metric": 'auc',
    "verbosity": -1,
    'reg_alpha': 0.33,
    'reg_lambda': 0.39,
    'random_state': 42,
}

# %%
seeds = [11, 19, 23, 27, 31, 37]
scores = []
test_preds = []

training_start_time = time()

for fold, month in enumerate(np.unique(dt_m)):
    seed = seeds[fold]
    seed_everything(seed)
    params['seed'] = seed
    
    start_time = time()
    print('Training on fold {}'.format(fold))
    
    is_val = dt_m.isin([month])
    x_train, y_train0 = df_train[~is_val], y_train[~is_val]
    x_val, y_val = df_train[is_val], y_train[is_val]
    print('Train: {}, Validation: {}'.format(len(x_train), len(x_val)))
    
    train_data = lgb.Dataset(x_train, label=y_train0)
    valid_data = lgb.Dataset(x_val, label=y_val)
    
    model = lgb.train(params, train_data, 
                      num_boost_round=3_000, 
                      valid_sets=valid_data, 
                      verbose_eval=100, 
                      early_stopping_rounds=100)
    
    print('Best iteration: ', model.best_iteration)
    
    y_pred_val = model.predict(x_val)
    auc = roc_auc_score(y_val, y_pred_val)
    scores.append(auc)
    print('OOF score for {} fold: {}'.format(fold, auc))
    save_to_disk(y_pred_val, 'y_pred_valid_fold{}.pkl'.format(fold))
    
    y_pred_test = model.predict(df_test)
    test_preds.append(y_pred_test)
    save_to_disk(y_pred_test, 'y_pred_test_fold{}.pkl'.format(fold))
    
    end_time = str(datetime.timedelta(seconds=time() - start_time))
    print('Fold {} finished in {}'.format(fold, end_time))
    
print('\nDONE')
print('Total time: {}'.format(str(datetime.timedelta(seconds=time() - training_start_time))))
# Out:
# Training on fold 0
# Train: 453219, Validation: 137321
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.884033
# [200]	valid_0's auc: 0.889811
# [300]	valid_0's auc: 0.896413
# [400]	valid_0's auc: 0.901741
# [500]	valid_0's auc: 0.905965
# [600]	valid_0's auc: 0.909074
# [700]	valid_0's auc: 0.911325
# [800]	valid_0's auc: 0.912805
# [900]	valid_0's auc: 0.913974
# [1000]	valid_0's auc: 0.915014
# [1100]	valid_0's auc: 0.916052
# [1200]	valid_0's auc: 0.916756
# [1300]	valid_0's auc: 0.917191
# [1400]	valid_0's auc: 0.917649
# [1500]	valid_0's auc: 0.917991
# [1600]	valid_0's auc: 0.918338
# [1700]	valid_0's auc: 0.918409
# [1800]	valid_0's auc: 0.918451
# [1900]	valid_0's auc: 0.918606
# Early stopping, best iteration is:
# [1888]	valid_0's auc: 0.918635
# Best iteration:  1888
# OOF score for 0 fold: 0.918634742724612
# Fold 0 finished in 0:23:38.241702
# Training on fold 1
# Train: 497955, Validation: 92585
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.907378
# [200]	valid_0's auc: 0.914059
# [300]	valid_0's auc: 0.919799
# [400]	valid_0's auc: 0.925336
# [500]	valid_0's auc: 0.930499
# [600]	valid_0's auc: 0.934282
# [700]	valid_0's auc: 0.937438
# [800]	valid_0's auc: 0.939575
# [900]	valid_0's auc: 0.941447
# [1000]	valid_0's auc: 0.942703
# [1100]	valid_0's auc: 0.943657
# [1200]	valid_0's auc: 0.944433
# [1300]	valid_0's auc: 0.944981
# [1400]	valid_0's auc: 0.945561
# [1500]	valid_0's auc: 0.945884
# [1600]	valid_0's auc: 0.946095
# [1700]	valid_0's auc: 0.946275
# [1800]	valid_0's auc: 0.946341
# Early stopping, best iteration is:
# [1741]	valid_0's auc: 0.946381
# Best iteration:  1741
# OOF score for 1 fold: 0.9463812099833465
# Fold 1 finished in 0:20:51.356544
# Training on fold 2
# Train: 504519, Validation: 86021
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.922804
# [200]	valid_0's auc: 0.929043
# [300]	valid_0's auc: 0.934079
# [400]	valid_0's auc: 0.938846
# [500]	valid_0's auc: 0.942963
# [600]	valid_0's auc: 0.945828
# [700]	valid_0's auc: 0.947913
# [800]	valid_0's auc: 0.949221
# [900]	valid_0's auc: 0.950191
# [1000]	valid_0's auc: 0.950773
# [1100]	valid_0's auc: 0.951194
# [1200]	valid_0's auc: 0.95145
# [1300]	valid_0's auc: 0.951725
# [1400]	valid_0's auc: 0.951808
# [1500]	valid_0's auc: 0.95189
# [1600]	valid_0's auc: 0.951877
# Early stopping, best iteration is:
# [1560]	valid_0's auc: 0.951926
# Best iteration:  1560
# OOF score for 2 fold: 0.9519255592731203
# Fold 2 finished in 0:18:44.599544
# Training on fold 3
# Train: 488908, Validation: 101632
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.907804
# [200]	valid_0's auc: 0.915561
# [300]	valid_0's auc: 0.922216
# [400]	valid_0's auc: 0.928199
# [500]	valid_0's auc: 0.933065
# [600]	valid_0's auc: 0.936456
# [700]	valid_0's auc: 0.938877
# [800]	valid_0's auc: 0.940503
# [900]	valid_0's auc: 0.94173
# [1000]	valid_0's auc: 0.942529
# [1100]	valid_0's auc: 0.943175
# [1200]	valid_0's auc: 0.943667
# [1300]	valid_0's auc: 0.944133
# [1400]	valid_0's auc: 0.944327
# [1500]	valid_0's auc: 0.944482
# [1600]	valid_0's auc: 0.944658
# [1700]	valid_0's auc: 0.944705
# [1800]	valid_0's auc: 0.9447
# Early stopping, best iteration is:
# [1723]	valid_0's auc: 0.94474
# Best iteration:  1723
# OOF score for 3 fold: 0.944740102759462
# Fold 3 finished in 0:20:25.880218
# Training on fold 4
# Train: 506885, Validation: 83655
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.908182
# [200]	valid_0's auc: 0.918196
# [300]	valid_0's auc: 0.926295
# [400]	valid_0's auc: 0.934131
# [500]	valid_0's auc: 0.940685
# [600]	valid_0's auc: 0.94526
# [700]	valid_0's auc: 0.948865
# [800]	valid_0's auc: 0.95084
# [900]	valid_0's auc: 0.952245
# [1000]	valid_0's auc: 0.953448
# [1100]	valid_0's auc: 0.954094
# [1200]	valid_0's auc: 0.954838
# [1300]	valid_0's auc: 0.955344
# [1400]	valid_0's auc: 0.955796
# [1500]	valid_0's auc: 0.956223
# [1600]	valid_0's auc: 0.956431
# [1700]	valid_0's auc: 0.956571
# [1800]	valid_0's auc: 0.956638
# [1900]	valid_0's auc: 0.956727
# [2000]	valid_0's auc: 0.956847
# [2100]	valid_0's auc: 0.956903
# [2200]	valid_0's auc: 0.956906
# Early stopping, best iteration is:
# [2157]	valid_0's auc: 0.956927
# Best iteration:  2157
# OOF score for 4 fold: 0.9569268764416583
# Fold 4 finished in 0:24:55.354666
# Training on fold 5
# Train: 501214, Validation: 89326
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.902529
# [200]	valid_0's auc: 0.910311
# [300]	valid_0's auc: 0.916993
# [400]	valid_0's auc: 0.923132
# [500]	valid_0's auc: 0.928299
# [600]	valid_0's auc: 0.932065
# [700]	valid_0's auc: 0.934985
# [800]	valid_0's auc: 0.936907
# [900]	valid_0's auc: 0.938157
# [1000]	valid_0's auc: 0.938955
# [1100]	valid_0's auc: 0.939594
# [1200]	valid_0's auc: 0.940103
# [1300]	valid_0's auc: 0.940459
# [1400]	valid_0's auc: 0.94063
# [1500]	valid_0's auc: 0.941033
# [1600]	valid_0's auc: 0.941182
# [1700]	valid_0's auc: 0.941143
# Early stopping, best iteration is:
# [1621]	valid_0's auc: 0.941215
# Best iteration:  1621
# OOF score for 5 fold: 0.9412145161956957
# Fold 5 finished in 0:18:47.541434
#
# DONE
# Total time: 2:07:23.449265

# %%
print('OOF score: avg %f, std %f, min %f' % (np.mean(scores), np.std(scores), np.min(scores)))
# Out:
# OOF score: avg 0.943304, std 0.012141, min 0.918635

# %% [markdown]
# # Submission

# %%
sub = pd.read_csv('../input/ieee-fraud-detection/sample_submission.csv')
sub['isFraud'] = np.average(test_preds, axis=0)
sub.to_csv('submission.csv', index=False)
